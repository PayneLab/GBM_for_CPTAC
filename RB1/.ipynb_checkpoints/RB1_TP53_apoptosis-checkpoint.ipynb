# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import re
import sys 
#sys.path.append('C:\\Users\\brittany henderson\\GitHub\\GBM_for_CPTAC\\')
#import cis_functions as f

import cptac
import cptac.utils as u

# %%
# note: pass reduced omics # CHECK would include non coding, but none in fm genes

def format_mutated_wt_comparison(reduced_omics_df):
    # Step 2 - Create binary column 
    reduced_omics_df['binary_mutations'] = np.where(
                reduced_omics_df[gene+'_Mutation_Status'] == 'Wildtype_Tumor', 'Wildtype', 'Mutated')

    # Step 3 - Format the dataframe correctly for the T-test(just omics and binary columns for tumors)
    tumors = reduced_omics_df[reduced_omics_df.Sample_Status == 'Tumor'] #drop Normal samples
    columns_to_drop = [gene+"_Mutation", gene+"_Location", gene+"_Mutation_Status", "Sample_Status"]
    mut_status = tumors.drop(columns_to_drop, axis = 1)

    return mut_status

# %%
def add_significance_col(results_df, num_comparisons):
    "bonferroni multiple hypothesis"""
    alpha = .05
    bonferroni_cutoff = alpha / num_comparisons
    
    pval = results_df['P_Value']
    if float(pval[0]) <= bonferroni_cutoff:
        results_df['Significant'] = True
    else: 
        results_df['Significant'] = False
    return results_df

def wrap_ttest_return_all(df, label_column, comparison_columns, total_tests, alpha=.05):
    try:
        #Verify precondition that label column exists and has exactly 2 unique values
        label_values = df[label_column].unique()
        if len(label_values) != 2:
            print("Incorrectly Formatted Dataframe! Label column must have exactly 2 unique values.")
            return None
        
        #Partition dataframe into two sets, one for each of the two unique values from the label column
        partition1 = df.loc[df[label_column] == label_values[0]]
        partition2 = df.loc[df[label_column] == label_values[1]]
        
        #Determine the number of real valued columns on which we will do t-tests
        #sites = len(comparison_columns.columns)
        number_of_comparisons = total_tests # ? phospho sites or num freq mut genes doing cis comp
        
        #Use a bonferroni correction to adjust for multiple testing by altering the p-value needed for acceptance
        bonferroni_cutoff = alpha/number_of_comparisons
        
        #Store all comparisons with their p-values in a dictionary
        all_comparisons = {}
        
        #Loop through each comparison column, perform the t-test, and determine whether it meets the significance cutoff'''
        for column in comparison_columns:
            stat, pval = scipy.stats.ttest_ind(partition1[column].dropna(axis=0), partition2[column].dropna(axis=0))
            all_comparisons[column] = pval
    
        #Sort dictionary to list smallest p-values first
        sorted_comparisons = sorted(all_comparisons.items(), key=lambda kv: kv[1])
        #Format as a dataframe and return to caller
        all_comparisons_df = pd.DataFrame.from_dict(sorted_comparisons)
        all_comparisons_df.columns = ['Comparison', 'P_Value']
        
                                               
        all_comparisons_sig_col = add_significance_col(all_comparisons_df, number_of_comparisons)
        return all_comparisons_sig_col
                                
    except:
        print("Incorrectly Formatted Dataframe!")
        return None

# %%
def format_pval_annotation(pval_symbol, x1, x2, line_start = .05, line_height=.05):
    # for manual adjustment to pval annotations
    
    y, h = line_start, line_height
    plt.plot([x1, x1, x2, x2], #draw horizontal line
             [y, y+h, y+h, y], #vertical line
             lw=1.5, color= '.3')
    plt.text((x1+x2)*.5, # half between x coord
             y+h, pval_symbol, horizontalalignment='center', verticalalignment='bottom', color = "black")

# used in pval_annotation
def get_pval_symbol(pval_df):
    if pval_df.iloc[0:,2].bool() == True:
        pval_symbol = '*'
    else:
        pval_symbol = 'ns'
    return pval_symbol

def pval_annotation(pval_df, plotted_df):
    # pval symbol
    num_pvals = len(pval_df)
    omics_col = plotted_df.columns[0]
    

    # annotation for Mutated and Wiltype
    if num_pvals == 1:
        mut_pval = pval_df.loc[pval_df.index == "Mutated/Wildtype"]
        mut_pval_symbol = get_pval_symbol(pval_df)
        
        x1, x2 = 0, 1   # columns (first column: 0, see plt.xticks())
        y, h = plotted_df[omics_col].max() + .05, .05     
        plt.plot([x1, x1, x2, x2], #draw horizontal line
                 [y, y+h, y+h, y], #vertical line
                 lw=1.5, color= '.3')
        plt.text((x1+x2)*.5, # half between x coord
                 y+h, mut_pval_symbol, horizontalalignment='center', verticalalignment='bottom', color = "black")
    
    # annotation for Missense, Truncation and Wildtype
    elif num_pvals == 2:
        # Missense
        miss_pval = pval_df.loc[pval_df.index == "Missense/Wildtype"]
        miss_pval_symbol = get_pval_symbol(miss_pval)
    
        x1, x2 = 0, 1   # columns (first column: 0, see plt.xticks())
        y, h = plotted_df[omics_col].max() + .05, .05     
        plt.plot([x1, x1, x2, x2], #draw horizontal line
                 [y, y+h, y+h, y], #vertical line
                 lw=1.5, color= '.3')
        plt.text((x1+x2)*.5, # half between x coord
                 y+h, miss_pval_symbol, horizontalalignment='center', verticalalignment='bottom', color = "black")
        
        # Truncation 
        trunc_pval = pval_df.loc[pval_df.index == "Truncation/Wildtype"]
        trunc_pval_symbol = get_pval_symbol(trunc_pval)
        
        x3, x4 = 0, 2   # columns (first column: 0, see plt.xticks())
        y2, h2 = plotted_df[omics_col].max() + .15, .05     
        plt.plot([x3, x3, x4, x4], #draw horizontal line
                 [y2, y2+h2, y2+h2, y2], #vertical line
                 lw=1.5, color= '.3')
        plt.text((x3+x4)*.5, # half between x coord
                 y2+h2, trunc_pval_symbol, horizontalalignment='center', verticalalignment='bottom', color = "black")

# %%
cptac.download(dataset="GBM")
# Out:
# True

# %%
brain = cptac.Gbm()
gene = ["RB1","TP53"]

# %%
#num_freq_mut_genes = len(freq_mut)
num_freq_mut_genes = 20
# Step 1 - Create dataframe in order to do comparisons with wrap_ttest - drop 
transrcpt_mutations = brain.join_omics_to_mutations(
    mutations_genes = ['RB1','TP53'], omics_df_name = 'transcriptomics', omics_genes = ["ARF1","CASP3","CASP7","CASP9","BID","APAF1"])
reduced_transcript_mutations = brain.reduce_multiindex(transrcpt_mutations, levels_to_drop=1) #single col labels
reduced_transcript_mutations = reduced_transcript_mutations.loc[reduced_transcript_mutations['Sample_Status'] == "Tumor"]
reduced_transcript_mutations
# Out:
# Warning: In joining the somatic_mutation table, no mutations were found for the following samples, so they were filled with Wildtype_Tumor or Wildtype_Normal: 98 samples for the RB1 gene, 76 samples for the TP53 gene (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py, line 5)
# Name       APAF1_transcriptomics  ARF1_transcriptomics  BID_transcriptomics  \
# Sample_ID
# S001               121584.924414          8.755904e+05        172824.575576
# S002               127543.335077          1.143540e+06        129224.679935
# S003               159717.892717          1.105102e+06        201906.077059
# S004               108777.078394          9.163683e+05         49391.078560
# S005               132169.668704          1.052542e+06         81962.838430
# ...                          ...                   ...                  ...
# S100                97803.075601          1.158203e+06         52321.706505
# S101               103953.919377          1.002822e+06        122409.939821
# S102                99337.423473          1.335898e+06        160571.493943
# S104               110694.913426          1.036239e+06         70921.123553
# S105               265295.344171          1.176823e+06        116049.984065
#
# Name       CASP3_transcriptomics  CASP7_transcriptomics  \
# Sample_ID
# S001               282155.799107           94757.856468
# S002               338958.989116          152333.359473
# S003               397178.747372          122607.182408
# S004               155861.917352           57094.934837
# S005               272108.246951           84073.177294
# ...                          ...                    ...
# S100               214369.829028          103235.606033
# S101               555823.390118           89316.707465
# S102               304616.038824           79108.511221
# S104               347881.513801          125266.990346
# S105               396746.858407          173928.472208
#
# Name       CASP9_transcriptomics                  RB1_Mutation  \
# Sample_ID
# S001                96998.516011                 [Splice_Site]
# S002                74437.051565             [Frame_Shift_Del]
# S003                63949.687681              [Wildtype_Tumor]
# S004                62775.668485  [Splice_Region, Splice_Site]
# S005                57767.798647              [Wildtype_Tumor]
# ...                          ...                           ...
# S100                59698.141303              [Wildtype_Tumor]
# S101                69803.234116              [Wildtype_Tumor]
# S102                54400.821984              [Wildtype_Tumor]
# S104                49014.662793              [Wildtype_Tumor]
# S105                79499.929809              [Wildtype_Tumor]
#
# Name                   RB1_Location RB1_Mutation_Status  \
# Sample_ID
# S001                [p.X654_splice]     Single_mutation
# S002                  [p.F117Lfs*8]     Single_mutation
# S003                  [No_mutation]      Wildtype_Tumor
# S004       [p.D349=, p.X605_splice]   Multiple_mutation
# S005                  [No_mutation]      Wildtype_Tumor
# ...                             ...                 ...
# S100                  [No_mutation]      Wildtype_Tumor
# S101                  [No_mutation]      Wildtype_Tumor
# S102                  [No_mutation]      Wildtype_Tumor
# S104                  [No_mutation]      Wildtype_Tumor
# S105                  [No_mutation]      Wildtype_Tumor
#
# Name                                TP53_Mutation         TP53_Location  \
# Sample_ID
# S001                          [Missense_Mutation]             [p.G266R]
# S002                          [Missense_Mutation]             [p.K132R]
# S003                             [Wildtype_Tumor]         [No_mutation]
# S004       [Missense_Mutation, Missense_Mutation]    [p.R248Q, p.R158H]
# S005                             [Wildtype_Tumor]         [No_mutation]
# ...                                           ...                   ...
# S100                             [Wildtype_Tumor]         [No_mutation]
# S101                             [Wildtype_Tumor]         [No_mutation]
# S102                             [Wildtype_Tumor]         [No_mutation]
# S104                             [Wildtype_Tumor]         [No_mutation]
# S105            [In_Frame_Ins, Missense_Mutation]  [p.A161dup, p.R156G]
#
# Name      TP53_Mutation_Status Sample_Status
# Sample_ID
# S001           Single_mutation         Tumor
# S002           Single_mutation         Tumor
# S003            Wildtype_Tumor         Tumor
# S004         Multiple_mutation         Tumor
# S005            Wildtype_Tumor         Tumor
# ...                        ...           ...
# S100            Wildtype_Tumor         Tumor
# S101            Wildtype_Tumor         Tumor
# S102            Wildtype_Tumor         Tumor
# S104            Wildtype_Tumor         Tumor
# S105         Multiple_mutation         Tumor
#
# [99 rows x 13 columns]

# %%
#Classify all mutations as 'mutation' and all wildtypes as 'wildtype'
reduced_transcript_mutations = reduced_transcript_mutations.replace({'Wildtype_Tumor':'Wildtype','Single_mutation':'Mutation','Multiple_mutation':'Mutation'})
reduced_transcript_mutations
# Out:
# Name       APAF1_transcriptomics  ARF1_transcriptomics  BID_transcriptomics  \
# Sample_ID
# S001               121584.924414          8.755904e+05        172824.575576
# S002               127543.335077          1.143540e+06        129224.679935
# S003               159717.892717          1.105102e+06        201906.077059
# S004               108777.078394          9.163683e+05         49391.078560
# S005               132169.668704          1.052542e+06         81962.838430
# ...                          ...                   ...                  ...
# S100                97803.075601          1.158203e+06         52321.706505
# S101               103953.919377          1.002822e+06        122409.939821
# S102                99337.423473          1.335898e+06        160571.493943
# S104               110694.913426          1.036239e+06         70921.123553
# S105               265295.344171          1.176823e+06        116049.984065
#
# Name       CASP3_transcriptomics  CASP7_transcriptomics  \
# Sample_ID
# S001               282155.799107           94757.856468
# S002               338958.989116          152333.359473
# S003               397178.747372          122607.182408
# S004               155861.917352           57094.934837
# S005               272108.246951           84073.177294
# ...                          ...                    ...
# S100               214369.829028          103235.606033
# S101               555823.390118           89316.707465
# S102               304616.038824           79108.511221
# S104               347881.513801          125266.990346
# S105               396746.858407          173928.472208
#
# Name       CASP9_transcriptomics                  RB1_Mutation  \
# Sample_ID
# S001                96998.516011                 [Splice_Site]
# S002                74437.051565             [Frame_Shift_Del]
# S003                63949.687681              [Wildtype_Tumor]
# S004                62775.668485  [Splice_Region, Splice_Site]
# S005                57767.798647              [Wildtype_Tumor]
# ...                          ...                           ...
# S100                59698.141303              [Wildtype_Tumor]
# S101                69803.234116              [Wildtype_Tumor]
# S102                54400.821984              [Wildtype_Tumor]
# S104                49014.662793              [Wildtype_Tumor]
# S105                79499.929809              [Wildtype_Tumor]
#
# Name                   RB1_Location RB1_Mutation_Status  \
# Sample_ID
# S001                [p.X654_splice]            Mutation
# S002                  [p.F117Lfs*8]            Mutation
# S003                  [No_mutation]            Wildtype
# S004       [p.D349=, p.X605_splice]            Mutation
# S005                  [No_mutation]            Wildtype
# ...                             ...                 ...
# S100                  [No_mutation]            Wildtype
# S101                  [No_mutation]            Wildtype
# S102                  [No_mutation]            Wildtype
# S104                  [No_mutation]            Wildtype
# S105                  [No_mutation]            Wildtype
#
# Name                                TP53_Mutation         TP53_Location  \
# Sample_ID
# S001                          [Missense_Mutation]             [p.G266R]
# S002                          [Missense_Mutation]             [p.K132R]
# S003                             [Wildtype_Tumor]         [No_mutation]
# S004       [Missense_Mutation, Missense_Mutation]    [p.R248Q, p.R158H]
# S005                             [Wildtype_Tumor]         [No_mutation]
# ...                                           ...                   ...
# S100                             [Wildtype_Tumor]         [No_mutation]
# S101                             [Wildtype_Tumor]         [No_mutation]
# S102                             [Wildtype_Tumor]         [No_mutation]
# S104                             [Wildtype_Tumor]         [No_mutation]
# S105            [In_Frame_Ins, Missense_Mutation]  [p.A161dup, p.R156G]
#
# Name      TP53_Mutation_Status Sample_Status
# Sample_ID
# S001                  Mutation         Tumor
# S002                  Mutation         Tumor
# S003                  Wildtype         Tumor
# S004                  Mutation         Tumor
# S005                  Wildtype         Tumor
# ...                        ...           ...
# S100                  Wildtype         Tumor
# S101                  Wildtype         Tumor
# S102                  Wildtype         Tumor
# S104                  Wildtype         Tumor
# S105                  Mutation         Tumor
#
# [99 rows x 13 columns]

# %%
for ind, row in reduced_transcript_mutations.iterrows():
    if row['RB1_Mutation_Status'] == 'Mutation' and row["TP53_Mutation_Status"] == 'Mutation':
        reduced_transcript_mutations.loc[ind, 'Mutation_Exclusivity'] = 'Both'
        
    elif row['RB1_Mutation_Status'] == 'Mutation' and row["TP53_Mutation_Status"] != 'Mutation':
        reduced_transcript_mutations.loc[ind, 'Mutation_Exclusivity'] = 'TP53_Only'
        
    elif row['RB1_Mutation_Status'] != 'Mutation' and row["TP53_Mutation_Status"] == 'Mutation':
        reduced_transcript_mutations.loc[ind, 'Mutation_Exclusivity'] = "RB1_Only"
        
    else:
        reduced_transcript_mutations.loc[ind, 'Mutation_Exclusivity'] = 'Neither'

# %%
reduced_transcript_mutations.head(100)
# Out:
# Name       APAF1_transcriptomics  ARF1_transcriptomics  BID_transcriptomics  \
# Sample_ID
# S001               121584.924414          8.755904e+05        172824.575576
# S002               127543.335077          1.143540e+06        129224.679935
# S003               159717.892717          1.105102e+06        201906.077059
# S004               108777.078394          9.163683e+05         49391.078560
# S005               132169.668704          1.052542e+06         81962.838430
# ...                          ...                   ...                  ...
# S100                97803.075601          1.158203e+06         52321.706505
# S101               103953.919377          1.002822e+06        122409.939821
# S102                99337.423473          1.335898e+06        160571.493943
# S104               110694.913426          1.036239e+06         70921.123553
# S105               265295.344171          1.176823e+06        116049.984065
#
# Name       CASP3_transcriptomics  CASP7_transcriptomics  \
# Sample_ID
# S001               282155.799107           94757.856468
# S002               338958.989116          152333.359473
# S003               397178.747372          122607.182408
# S004               155861.917352           57094.934837
# S005               272108.246951           84073.177294
# ...                          ...                    ...
# S100               214369.829028          103235.606033
# S101               555823.390118           89316.707465
# S102               304616.038824           79108.511221
# S104               347881.513801          125266.990346
# S105               396746.858407          173928.472208
#
# Name       CASP9_transcriptomics                  RB1_Mutation  \
# Sample_ID
# S001                96998.516011                 [Splice_Site]
# S002                74437.051565             [Frame_Shift_Del]
# S003                63949.687681              [Wildtype_Tumor]
# S004                62775.668485  [Splice_Region, Splice_Site]
# S005                57767.798647              [Wildtype_Tumor]
# ...                          ...                           ...
# S100                59698.141303              [Wildtype_Tumor]
# S101                69803.234116              [Wildtype_Tumor]
# S102                54400.821984              [Wildtype_Tumor]
# S104                49014.662793              [Wildtype_Tumor]
# S105                79499.929809              [Wildtype_Tumor]
#
# Name                   RB1_Location RB1_Mutation_Status  \
# Sample_ID
# S001                [p.X654_splice]            Mutation
# S002                  [p.F117Lfs*8]            Mutation
# S003                  [No_mutation]            Wildtype
# S004       [p.D349=, p.X605_splice]            Mutation
# S005                  [No_mutation]            Wildtype
# ...                             ...                 ...
# S100                  [No_mutation]            Wildtype
# S101                  [No_mutation]            Wildtype
# S102                  [No_mutation]            Wildtype
# S104                  [No_mutation]            Wildtype
# S105                  [No_mutation]            Wildtype
#
# Name                                TP53_Mutation         TP53_Location  \
# Sample_ID
# S001                          [Missense_Mutation]             [p.G266R]
# S002                          [Missense_Mutation]             [p.K132R]
# S003                             [Wildtype_Tumor]         [No_mutation]
# S004       [Missense_Mutation, Missense_Mutation]    [p.R248Q, p.R158H]
# S005                             [Wildtype_Tumor]         [No_mutation]
# ...                                           ...                   ...
# S100                             [Wildtype_Tumor]         [No_mutation]
# S101                             [Wildtype_Tumor]         [No_mutation]
# S102                             [Wildtype_Tumor]         [No_mutation]
# S104                             [Wildtype_Tumor]         [No_mutation]
# S105            [In_Frame_Ins, Missense_Mutation]  [p.A161dup, p.R156G]
#
# Name      TP53_Mutation_Status Sample_Status Mutation_Exclusivity
# Sample_ID
# S001                  Mutation         Tumor                 Both
# S002                  Mutation         Tumor                 Both
# S003                  Wildtype         Tumor              Neither
# S004                  Mutation         Tumor                 Both
# S005                  Wildtype         Tumor              Neither
# ...                        ...           ...                  ...
# S100                  Wildtype         Tumor              Neither
# S101                  Wildtype         Tumor              Neither
# S102                  Wildtype         Tumor              Neither
# S104                  Wildtype         Tumor              Neither
# S105                  Mutation         Tumor             RB1_Only
#
# [99 rows x 14 columns]

# %%
#num_freq_mut_genes = len(freq_mut) 
num_freq_mut_genes = 20
trans_col_list = ["APAF1"+'_transcriptomics', "ARF1_transcriptomics","BID_transcriptomics","CASP3_transcriptomics","CASP7_transcriptomics","CASP9_transcriptomics"]

# %%
# compare wildtype (neither) and Both
Both_wt = reduced_transcript_mutations.loc[(reduced_transcript_mutations['Mutation_Exclusivity'] != "TP53_Only")]
Both_wt = Both_wt.loc[(Both_wt['Mutation_Exclusivity'] != "RB1_Only")]
print("Doing t-test comparison for Both and Wildtype")
RB1_results_both = wrap_ttest_return_all(Both_wt, 'Mutation_Exclusivity',trans_col_list, num_freq_mut_genes)
RB1_results_both = RB1_results_both.rename(index = {0: "Both/Wildtype"})
RB1_results_both
# Out:
# Doing t-test comparison for Both and Wildtype
#                           Comparison   P_Value  Significant
# Both/Wildtype  CASP7_transcriptomics  0.064486        False
# 1              CASP3_transcriptomics  0.067417        False
# 2                BID_transcriptomics  0.379926        False
# 3              CASP9_transcriptomics  0.440074        False
# 4               ARF1_transcriptomics  0.826987        False
# 5              APAF1_transcriptomics  0.980519        False

# %%
cols_drop = ['RB1_Mutation','TP53_Mutation','RB1_Location','TP53_Location','RB1_Mutation_Status','TP53_Mutation_Status','Sample_Status']
reduced_transcript_mutations = reduced_transcript_mutations.drop(cols_drop,axis=1)

# %%
melted = pd.melt(reduced_transcript_mutations, id_vars='Mutation_Exclusivity')
melted
# Out:
#     Mutation_Exclusivity                   Name          value
# 0                   Both  APAF1_transcriptomics  121584.924414
# 1                   Both  APAF1_transcriptomics  127543.335077
# 2                Neither  APAF1_transcriptomics  159717.892717
# 3                   Both  APAF1_transcriptomics  108777.078394
# 4                Neither  APAF1_transcriptomics  132169.668704
# ..                   ...                    ...            ...
# 589              Neither  CASP9_transcriptomics   59698.141303
# 590              Neither  CASP9_transcriptomics   69803.234116
# 591              Neither  CASP9_transcriptomics   54400.821984
# 592              Neither  CASP9_transcriptomics   49014.662793
# 593             RB1_Only  CASP9_transcriptomics   79499.929809
#
# [594 rows x 3 columns]

# %%
gene = "RB1"
plt.rcParams['figure.figsize']=(20,15)
sns.set(font_scale = 1.3)
cis_boxplot = sns.boxplot(data = melted, x = 'Name',
                          y = 'value', hue='Mutation_Exclusivity', hue_order = ['Neither', 'Both', 'RB1_Only', "TP53_Only"], showfliers = False)  
cis_boxplot.set_title(gene + " Effect on E2F1 target genes" +" Proteomics in Glioblastoma Tumors\n")
cis_boxplot = sns.stripplot(data= melted, x = 'Name',
                            y = 'value', hue='Mutation_Exclusivity',jitter = True, color = ".5", hue_order = ['Neither', "Both",'RB1_Only', "TP53_Only"])
cis_boxplot.set(xlabel = "\n"+gene + " Mutation Status in Tumors", ylabel = 'transcriptomics')
cis_boxplot.set_xticklabels(cis_boxplot.get_xticklabels())

# format legend
handles, labels = cis_boxplot.get_legend_handles_labels()
plt.legend(handles[0:4], labels[0:4])


plt.show()
plt.clf()
plt.close()

# %% [markdown]
# # Proteomics

# %%
gene = ["RB1","TP53"]
#num_freq_mut_genes = len(freq_mut)
num_freq_mut_genes = 20
# Step 1 - Create dataframe in order to do comparisons with wrap_ttest - drop 
proteomic_mutations = brain.join_omics_to_mutations(
    mutations_genes = gene, omics_df_name = 'proteomics', omics_genes = ["ARF1","CASP3","CASP7","CASP9","BID","APAF1"])

proteomic_mutations
# Out:
# Warning: In joining the somatic_mutation table, no mutations were found for the following samples, so they were filled with Wildtype_Tumor or Wildtype_Normal: 99 samples for the RB1 gene, 77 samples for the TP53 gene (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py, line 6)
# Name       ARF1_proteomics  CASP3_proteomics  CASP7_proteomics  \
# Sample_ID
# S001             -1.079632         -0.103299         -0.478298
# S002                   NaN         -0.068945         -0.051566
# S003                   NaN         -0.359319         -0.246385
# S004             -0.080557         -0.912002         -0.940367
# S005             -1.079538          0.185203         -0.215475
# ...                    ...               ...               ...
# S111              0.563308         -2.175506         -0.614856
# S112                   NaN         -1.586803         -1.149258
# S113                   NaN         -2.055661         -1.059149
# S114              0.046421         -1.974150         -1.338703
# S115                   NaN         -1.575213         -1.299305
#
# Name       CASP9_proteomics  BID_proteomics  APAF1_proteomics  \
# Sample_ID
# S001               0.104011        0.121788         -0.082649
# S002               0.273644        0.156544          0.152627
# S003               0.113761        0.188308         -0.012196
# S004              -0.237273       -0.239060         -0.512124
# S005              -0.284076       -0.345157         -0.295338
# ...                     ...             ...               ...
# S111              -0.069430       -0.403765         -0.738951
# S112              -0.438419       -0.419027         -0.747015
# S113              -0.348722       -0.398427         -1.012836
# S114              -0.620998       -0.775101         -0.985775
# S115              -0.616942       -0.521992         -0.729908
#
# Name                       RB1_Mutation              RB1_Location  \
# Sample_ID
# S001                      [Splice_Site]           [p.X654_splice]
# S002                  [Frame_Shift_Del]             [p.F117Lfs*8]
# S003                   [Wildtype_Tumor]             [No_mutation]
# S004       [Splice_Region, Splice_Site]  [p.D349=, p.X605_splice]
# S005                   [Wildtype_Tumor]             [No_mutation]
# ...                                 ...                       ...
# S111                  [Wildtype_Normal]             [No_mutation]
# S112                  [Wildtype_Normal]             [No_mutation]
# S113                  [Wildtype_Normal]             [No_mutation]
# S114                  [Wildtype_Normal]             [No_mutation]
# S115                  [Wildtype_Normal]             [No_mutation]
#
# Name      RB1_Mutation_Status                           TP53_Mutation  \
# Sample_ID
# S001          Single_mutation                     [Missense_Mutation]
# S002          Single_mutation                     [Missense_Mutation]
# S003           Wildtype_Tumor                        [Wildtype_Tumor]
# S004        Multiple_mutation  [Missense_Mutation, Missense_Mutation]
# S005           Wildtype_Tumor                        [Wildtype_Tumor]
# ...                       ...                                     ...
# S111          Wildtype_Normal                       [Wildtype_Normal]
# S112          Wildtype_Normal                       [Wildtype_Normal]
# S113          Wildtype_Normal                       [Wildtype_Normal]
# S114          Wildtype_Normal                       [Wildtype_Normal]
# S115          Wildtype_Normal                       [Wildtype_Normal]
#
# Name            TP53_Location TP53_Mutation_Status Sample_Status
# Sample_ID
# S001                [p.G266R]      Single_mutation         Tumor
# S002                [p.K132R]      Single_mutation         Tumor
# S003            [No_mutation]       Wildtype_Tumor         Tumor
# S004       [p.R248Q, p.R158H]    Multiple_mutation         Tumor
# S005            [No_mutation]       Wildtype_Tumor         Tumor
# ...                       ...                  ...           ...
# S111            [No_mutation]      Wildtype_Normal        Normal
# S112            [No_mutation]      Wildtype_Normal        Normal
# S113            [No_mutation]      Wildtype_Normal        Normal
# S114            [No_mutation]      Wildtype_Normal        Normal
# S115            [No_mutation]      Wildtype_Normal        Normal
#
# [109 rows x 13 columns]

# %%
#Classify all mutations as 'mutation' and all wildtypes as 'wildtype'
proteomic_mutations = proteomic_mutations.replace({'Wildtype_Tumor':'Wildtype','Single_mutation':'Mutation','Multiple_mutation':'Mutation'})
proteomic_mutations
# Out:
# Name       ARF1_proteomics  CASP3_proteomics  CASP7_proteomics  \
# Sample_ID
# S001             -1.079632         -0.103299         -0.478298
# S002                   NaN         -0.068945         -0.051566
# S003                   NaN         -0.359319         -0.246385
# S004             -0.080557         -0.912002         -0.940367
# S005             -1.079538          0.185203         -0.215475
# ...                    ...               ...               ...
# S111              0.563308         -2.175506         -0.614856
# S112                   NaN         -1.586803         -1.149258
# S113                   NaN         -2.055661         -1.059149
# S114              0.046421         -1.974150         -1.338703
# S115                   NaN         -1.575213         -1.299305
#
# Name       CASP9_proteomics  BID_proteomics  APAF1_proteomics  \
# Sample_ID
# S001               0.104011        0.121788         -0.082649
# S002               0.273644        0.156544          0.152627
# S003               0.113761        0.188308         -0.012196
# S004              -0.237273       -0.239060         -0.512124
# S005              -0.284076       -0.345157         -0.295338
# ...                     ...             ...               ...
# S111              -0.069430       -0.403765         -0.738951
# S112              -0.438419       -0.419027         -0.747015
# S113              -0.348722       -0.398427         -1.012836
# S114              -0.620998       -0.775101         -0.985775
# S115              -0.616942       -0.521992         -0.729908
#
# Name                       RB1_Mutation              RB1_Location  \
# Sample_ID
# S001                      [Splice_Site]           [p.X654_splice]
# S002                  [Frame_Shift_Del]             [p.F117Lfs*8]
# S003                   [Wildtype_Tumor]             [No_mutation]
# S004       [Splice_Region, Splice_Site]  [p.D349=, p.X605_splice]
# S005                   [Wildtype_Tumor]             [No_mutation]
# ...                                 ...                       ...
# S111                  [Wildtype_Normal]             [No_mutation]
# S112                  [Wildtype_Normal]             [No_mutation]
# S113                  [Wildtype_Normal]             [No_mutation]
# S114                  [Wildtype_Normal]             [No_mutation]
# S115                  [Wildtype_Normal]             [No_mutation]
#
# Name      RB1_Mutation_Status                           TP53_Mutation  \
# Sample_ID
# S001                 Mutation                     [Missense_Mutation]
# S002                 Mutation                     [Missense_Mutation]
# S003                 Wildtype                        [Wildtype_Tumor]
# S004                 Mutation  [Missense_Mutation, Missense_Mutation]
# S005                 Wildtype                        [Wildtype_Tumor]
# ...                       ...                                     ...
# S111          Wildtype_Normal                       [Wildtype_Normal]
# S112          Wildtype_Normal                       [Wildtype_Normal]
# S113          Wildtype_Normal                       [Wildtype_Normal]
# S114          Wildtype_Normal                       [Wildtype_Normal]
# S115          Wildtype_Normal                       [Wildtype_Normal]
#
# Name            TP53_Location TP53_Mutation_Status Sample_Status
# Sample_ID
# S001                [p.G266R]             Mutation         Tumor
# S002                [p.K132R]             Mutation         Tumor
# S003            [No_mutation]             Wildtype         Tumor
# S004       [p.R248Q, p.R158H]             Mutation         Tumor
# S005            [No_mutation]             Wildtype         Tumor
# ...                       ...                  ...           ...
# S111            [No_mutation]      Wildtype_Normal        Normal
# S112            [No_mutation]      Wildtype_Normal        Normal
# S113            [No_mutation]      Wildtype_Normal        Normal
# S114            [No_mutation]      Wildtype_Normal        Normal
# S115            [No_mutation]      Wildtype_Normal        Normal
#
# [109 rows x 13 columns]

# %%
for ind, row in proteomic_mutations.iterrows():
    if row['RB1_Mutation_Status'] == 'Mutation' and row["TP53_Mutation_Status"] == 'Mutation':
        proteomic_mutations.loc[ind, 'Mutation_Exclusivity'] = 'Both'
        
    elif row['RB1_Mutation_Status'] == 'Mutation' and row["TP53_Mutation_Status"] != 'Mutation':
        proteomic_mutations.loc[ind, 'Mutation_Exclusivity'] = 'TP53_Only'
        
    elif row['RB1_Mutation_Status'] != 'Mutation' and row["TP53_Mutation_Status"] == 'Mutation':
        proteomic_mutations.loc[ind, 'Mutation_Exclusivity'] = "RB1_Only"
        
    else:
        proteomic_mutations.loc[ind, 'Mutation_Exclusivity'] = 'Neither'

# %%
proteomic_mutations
# Out:
# Name       ARF1_proteomics  CASP3_proteomics  CASP7_proteomics  \
# Sample_ID
# S001             -1.079632         -0.103299         -0.478298
# S002                   NaN         -0.068945         -0.051566
# S003                   NaN         -0.359319         -0.246385
# S004             -0.080557         -0.912002         -0.940367
# S005             -1.079538          0.185203         -0.215475
# ...                    ...               ...               ...
# S111              0.563308         -2.175506         -0.614856
# S112                   NaN         -1.586803         -1.149258
# S113                   NaN         -2.055661         -1.059149
# S114              0.046421         -1.974150         -1.338703
# S115                   NaN         -1.575213         -1.299305
#
# Name       CASP9_proteomics  BID_proteomics  APAF1_proteomics  \
# Sample_ID
# S001               0.104011        0.121788         -0.082649
# S002               0.273644        0.156544          0.152627
# S003               0.113761        0.188308         -0.012196
# S004              -0.237273       -0.239060         -0.512124
# S005              -0.284076       -0.345157         -0.295338
# ...                     ...             ...               ...
# S111              -0.069430       -0.403765         -0.738951
# S112              -0.438419       -0.419027         -0.747015
# S113              -0.348722       -0.398427         -1.012836
# S114              -0.620998       -0.775101         -0.985775
# S115              -0.616942       -0.521992         -0.729908
#
# Name                       RB1_Mutation              RB1_Location  \
# Sample_ID
# S001                      [Splice_Site]           [p.X654_splice]
# S002                  [Frame_Shift_Del]             [p.F117Lfs*8]
# S003                   [Wildtype_Tumor]             [No_mutation]
# S004       [Splice_Region, Splice_Site]  [p.D349=, p.X605_splice]
# S005                   [Wildtype_Tumor]             [No_mutation]
# ...                                 ...                       ...
# S111                  [Wildtype_Normal]             [No_mutation]
# S112                  [Wildtype_Normal]             [No_mutation]
# S113                  [Wildtype_Normal]             [No_mutation]
# S114                  [Wildtype_Normal]             [No_mutation]
# S115                  [Wildtype_Normal]             [No_mutation]
#
# Name      RB1_Mutation_Status                           TP53_Mutation  \
# Sample_ID
# S001                 Mutation                     [Missense_Mutation]
# S002                 Mutation                     [Missense_Mutation]
# S003                 Wildtype                        [Wildtype_Tumor]
# S004                 Mutation  [Missense_Mutation, Missense_Mutation]
# S005                 Wildtype                        [Wildtype_Tumor]
# ...                       ...                                     ...
# S111          Wildtype_Normal                       [Wildtype_Normal]
# S112          Wildtype_Normal                       [Wildtype_Normal]
# S113          Wildtype_Normal                       [Wildtype_Normal]
# S114          Wildtype_Normal                       [Wildtype_Normal]
# S115          Wildtype_Normal                       [Wildtype_Normal]
#
# Name            TP53_Location TP53_Mutation_Status Sample_Status  \
# Sample_ID
# S001                [p.G266R]             Mutation         Tumor
# S002                [p.K132R]             Mutation         Tumor
# S003            [No_mutation]             Wildtype         Tumor
# S004       [p.R248Q, p.R158H]             Mutation         Tumor
# S005            [No_mutation]             Wildtype         Tumor
# ...                       ...                  ...           ...
# S111            [No_mutation]      Wildtype_Normal        Normal
# S112            [No_mutation]      Wildtype_Normal        Normal
# S113            [No_mutation]      Wildtype_Normal        Normal
# S114            [No_mutation]      Wildtype_Normal        Normal
# S115            [No_mutation]      Wildtype_Normal        Normal
#
# Name      Mutation_Exclusivity
# Sample_ID
# S001                      Both
# S002                      Both
# S003                   Neither
# S004                      Both
# S005                   Neither
# ...                        ...
# S111                   Neither
# S112                   Neither
# S113                   Neither
# S114                   Neither
# S115                   Neither
#
# [109 rows x 14 columns]

# %%
#num_freq_mut_genes = len(freq_mut) 
num_freq_mut_genes = 20
prot_col_list = ["APAF1"+'_proteomics', "ARF1_proteomics","BID_proteomics","CASP3_proteomics","CASP7_proteomics","CASP9_proteomics"]
proteomic_mutations
# Out:
# Name       ARF1_proteomics  CASP3_proteomics  CASP7_proteomics  \
# Sample_ID
# S001             -1.079632         -0.103299         -0.478298
# S002                   NaN         -0.068945         -0.051566
# S003                   NaN         -0.359319         -0.246385
# S004             -0.080557         -0.912002         -0.940367
# S005             -1.079538          0.185203         -0.215475
# ...                    ...               ...               ...
# S111              0.563308         -2.175506         -0.614856
# S112                   NaN         -1.586803         -1.149258
# S113                   NaN         -2.055661         -1.059149
# S114              0.046421         -1.974150         -1.338703
# S115                   NaN         -1.575213         -1.299305
#
# Name       CASP9_proteomics  BID_proteomics  APAF1_proteomics  \
# Sample_ID
# S001               0.104011        0.121788         -0.082649
# S002               0.273644        0.156544          0.152627
# S003               0.113761        0.188308         -0.012196
# S004              -0.237273       -0.239060         -0.512124
# S005              -0.284076       -0.345157         -0.295338
# ...                     ...             ...               ...
# S111              -0.069430       -0.403765         -0.738951
# S112              -0.438419       -0.419027         -0.747015
# S113              -0.348722       -0.398427         -1.012836
# S114              -0.620998       -0.775101         -0.985775
# S115              -0.616942       -0.521992         -0.729908
#
# Name                       RB1_Mutation              RB1_Location  \
# Sample_ID
# S001                      [Splice_Site]           [p.X654_splice]
# S002                  [Frame_Shift_Del]             [p.F117Lfs*8]
# S003                   [Wildtype_Tumor]             [No_mutation]
# S004       [Splice_Region, Splice_Site]  [p.D349=, p.X605_splice]
# S005                   [Wildtype_Tumor]             [No_mutation]
# ...                                 ...                       ...
# S111                  [Wildtype_Normal]             [No_mutation]
# S112                  [Wildtype_Normal]             [No_mutation]
# S113                  [Wildtype_Normal]             [No_mutation]
# S114                  [Wildtype_Normal]             [No_mutation]
# S115                  [Wildtype_Normal]             [No_mutation]
#
# Name      RB1_Mutation_Status                           TP53_Mutation  \
# Sample_ID
# S001                 Mutation                     [Missense_Mutation]
# S002                 Mutation                     [Missense_Mutation]
# S003                 Wildtype                        [Wildtype_Tumor]
# S004                 Mutation  [Missense_Mutation, Missense_Mutation]
# S005                 Wildtype                        [Wildtype_Tumor]
# ...                       ...                                     ...
# S111          Wildtype_Normal                       [Wildtype_Normal]
# S112          Wildtype_Normal                       [Wildtype_Normal]
# S113          Wildtype_Normal                       [Wildtype_Normal]
# S114          Wildtype_Normal                       [Wildtype_Normal]
# S115          Wildtype_Normal                       [Wildtype_Normal]
#
# Name            TP53_Location TP53_Mutation_Status Sample_Status  \
# Sample_ID
# S001                [p.G266R]             Mutation         Tumor
# S002                [p.K132R]             Mutation         Tumor
# S003            [No_mutation]             Wildtype         Tumor
# S004       [p.R248Q, p.R158H]             Mutation         Tumor
# S005            [No_mutation]             Wildtype         Tumor
# ...                       ...                  ...           ...
# S111            [No_mutation]      Wildtype_Normal        Normal
# S112            [No_mutation]      Wildtype_Normal        Normal
# S113            [No_mutation]      Wildtype_Normal        Normal
# S114            [No_mutation]      Wildtype_Normal        Normal
# S115            [No_mutation]      Wildtype_Normal        Normal
#
# Name      Mutation_Exclusivity
# Sample_ID
# S001                      Both
# S002                      Both
# S003                   Neither
# S004                      Both
# S005                   Neither
# ...                        ...
# S111                   Neither
# S112                   Neither
# S113                   Neither
# S114                   Neither
# S115                   Neither
#
# [109 rows x 14 columns]

# %%
# compare wildtype (neither) and Both
Prot_Both_wt = proteomic_mutations.loc[(proteomic_mutations['Mutation_Exclusivity'] != "TP53_Only")]
Prot_Both_wt = Prot_Both_wt.loc[(Prot_Both_wt['Mutation_Exclusivity'] != "RB1_Only")]
Prot_Both_wt
# Out:
# Name       ARF1_proteomics  CASP3_proteomics  CASP7_proteomics  \
# Sample_ID
# S001             -1.079632         -0.103299         -0.478298
# S002                   NaN         -0.068945         -0.051566
# S003                   NaN         -0.359319         -0.246385
# S004             -0.080557         -0.912002         -0.940367
# S005             -1.079538          0.185203         -0.215475
# ...                    ...               ...               ...
# S111              0.563308         -2.175506         -0.614856
# S112                   NaN         -1.586803         -1.149258
# S113                   NaN         -2.055661         -1.059149
# S114              0.046421         -1.974150         -1.338703
# S115                   NaN         -1.575213         -1.299305
#
# Name       CASP9_proteomics  BID_proteomics  APAF1_proteomics  \
# Sample_ID
# S001               0.104011        0.121788         -0.082649
# S002               0.273644        0.156544          0.152627
# S003               0.113761        0.188308         -0.012196
# S004              -0.237273       -0.239060         -0.512124
# S005              -0.284076       -0.345157         -0.295338
# ...                     ...             ...               ...
# S111              -0.069430       -0.403765         -0.738951
# S112              -0.438419       -0.419027         -0.747015
# S113              -0.348722       -0.398427         -1.012836
# S114              -0.620998       -0.775101         -0.985775
# S115              -0.616942       -0.521992         -0.729908
#
# Name                       RB1_Mutation              RB1_Location  \
# Sample_ID
# S001                      [Splice_Site]           [p.X654_splice]
# S002                  [Frame_Shift_Del]             [p.F117Lfs*8]
# S003                   [Wildtype_Tumor]             [No_mutation]
# S004       [Splice_Region, Splice_Site]  [p.D349=, p.X605_splice]
# S005                   [Wildtype_Tumor]             [No_mutation]
# ...                                 ...                       ...
# S111                  [Wildtype_Normal]             [No_mutation]
# S112                  [Wildtype_Normal]             [No_mutation]
# S113                  [Wildtype_Normal]             [No_mutation]
# S114                  [Wildtype_Normal]             [No_mutation]
# S115                  [Wildtype_Normal]             [No_mutation]
#
# Name      RB1_Mutation_Status                           TP53_Mutation  \
# Sample_ID
# S001                 Mutation                     [Missense_Mutation]
# S002                 Mutation                     [Missense_Mutation]
# S003                 Wildtype                        [Wildtype_Tumor]
# S004                 Mutation  [Missense_Mutation, Missense_Mutation]
# S005                 Wildtype                        [Wildtype_Tumor]
# ...                       ...                                     ...
# S111          Wildtype_Normal                       [Wildtype_Normal]
# S112          Wildtype_Normal                       [Wildtype_Normal]
# S113          Wildtype_Normal                       [Wildtype_Normal]
# S114          Wildtype_Normal                       [Wildtype_Normal]
# S115          Wildtype_Normal                       [Wildtype_Normal]
#
# Name            TP53_Location TP53_Mutation_Status Sample_Status  \
# Sample_ID
# S001                [p.G266R]             Mutation         Tumor
# S002                [p.K132R]             Mutation         Tumor
# S003            [No_mutation]             Wildtype         Tumor
# S004       [p.R248Q, p.R158H]             Mutation         Tumor
# S005            [No_mutation]             Wildtype         Tumor
# ...                       ...                  ...           ...
# S111            [No_mutation]      Wildtype_Normal        Normal
# S112            [No_mutation]      Wildtype_Normal        Normal
# S113            [No_mutation]      Wildtype_Normal        Normal
# S114            [No_mutation]      Wildtype_Normal        Normal
# S115            [No_mutation]      Wildtype_Normal        Normal
#
# Name      Mutation_Exclusivity
# Sample_ID
# S001                      Both
# S002                      Both
# S003                   Neither
# S004                      Both
# S005                   Neither
# ...                        ...
# S111                   Neither
# S112                   Neither
# S113                   Neither
# S114                   Neither
# S115                   Neither
#
# [83 rows x 14 columns]

# %%
print("Doing t-test comparison for Both and Wildtype")
RB1_results_both = u.wrap_ttest(Prot_Both_wt, 'Mutation_Exclusivity',prot_col_list, num_freq_mut_genes,return_all=True)
#RB1_results_both = RB1_results_both.rename(index = {0: "Both/Wildtype"})
RB1_results_both
# Out:
# Doing t-test comparison for Both and Wildtype
# 6 significant comparisons!
#          Comparison   P_Value
# 0  CASP9_proteomics  0.062638
# 1  CASP7_proteomics  0.173310
# 2  APAF1_proteomics  0.295184
# 3  CASP3_proteomics  0.703487
# 4   ARF1_proteomics  0.790643
# 5    BID_proteomics  0.803008

# %%
Prot_Both_wt
# Out:
# Name       ARF1_proteomics  CASP3_proteomics  CASP7_proteomics  \
# Sample_ID
# S001             -1.079632         -0.103299         -0.478298
# S002                   NaN         -0.068945         -0.051566
# S003                   NaN         -0.359319         -0.246385
# S004             -0.080557         -0.912002         -0.940367
# S005             -1.079538          0.185203         -0.215475
# ...                    ...               ...               ...
# S111              0.563308         -2.175506         -0.614856
# S112                   NaN         -1.586803         -1.149258
# S113                   NaN         -2.055661         -1.059149
# S114              0.046421         -1.974150         -1.338703
# S115                   NaN         -1.575213         -1.299305
#
# Name       CASP7_proteomics  CASP9_proteomics  BID_proteomics  \
# Sample_ID
# S001              -0.478298          0.104011        0.121788
# S002              -0.051566          0.273644        0.156544
# S003              -0.246385          0.113761        0.188308
# S004              -0.940367         -0.237273       -0.239060
# S005              -0.215475         -0.284076       -0.345157
# ...                     ...               ...             ...
# S111              -0.614856         -0.069430       -0.403765
# S112              -1.149258         -0.438419       -0.419027
# S113              -1.059149         -0.348722       -0.398427
# S114              -1.338703         -0.620998       -0.775101
# S115              -1.299305         -0.616942       -0.521992
#
# Name       APAF1_proteomics                  RB1_Mutation  \
# Sample_ID
# S001              -0.082649                 [Splice_Site]
# S002               0.152627             [Frame_Shift_Del]
# S003              -0.012196              [Wildtype_Tumor]
# S004              -0.512124  [Splice_Region, Splice_Site]
# S005              -0.295338              [Wildtype_Tumor]
# ...                     ...                           ...
# S111              -0.738951             [Wildtype_Normal]
# S112              -0.747015             [Wildtype_Normal]
# S113              -1.012836             [Wildtype_Normal]
# S114              -0.985775             [Wildtype_Normal]
# S115              -0.729908             [Wildtype_Normal]
#
# Name                   RB1_Location RB1_Mutation_Status  \
# Sample_ID
# S001                [p.X654_splice]            Mutation
# S002                  [p.F117Lfs*8]            Mutation
# S003                  [No_mutation]            Wildtype
# S004       [p.D349=, p.X605_splice]            Mutation
# S005                  [No_mutation]            Wildtype
# ...                             ...                 ...
# S111                  [No_mutation]     Wildtype_Normal
# S112                  [No_mutation]     Wildtype_Normal
# S113                  [No_mutation]     Wildtype_Normal
# S114                  [No_mutation]     Wildtype_Normal
# S115                  [No_mutation]     Wildtype_Normal
#
# Name                                TP53_Mutation       TP53_Location  \
# Sample_ID
# S001                          [Missense_Mutation]           [p.G266R]
# S002                          [Missense_Mutation]           [p.K132R]
# S003                             [Wildtype_Tumor]       [No_mutation]
# S004       [Missense_Mutation, Missense_Mutation]  [p.R248Q, p.R158H]
# S005                             [Wildtype_Tumor]       [No_mutation]
# ...                                           ...                 ...
# S111                            [Wildtype_Normal]       [No_mutation]
# S112                            [Wildtype_Normal]       [No_mutation]
# S113                            [Wildtype_Normal]       [No_mutation]
# S114                            [Wildtype_Normal]       [No_mutation]
# S115                            [Wildtype_Normal]       [No_mutation]
#
# Name      TP53_Mutation_Status Sample_Status Mutation_Exclusivity
# Sample_ID
# S001                  Mutation         Tumor                 Both
# S002                  Mutation         Tumor                 Both
# S003                  Wildtype         Tumor              Neither
# S004                  Mutation         Tumor                 Both
# S005                  Wildtype         Tumor              Neither
# ...                        ...           ...                  ...
# S111           Wildtype_Normal        Normal              Neither
# S112           Wildtype_Normal        Normal              Neither
# S113           Wildtype_Normal        Normal              Neither
# S114           Wildtype_Normal        Normal              Neither
# S115           Wildtype_Normal        Normal              Neither
#
# [83 rows x 15 columns]
