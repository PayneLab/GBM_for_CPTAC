# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import re

import cptac
import cptac.utils as u

# %%
b = cptac.Gbm()

# %%
p = b.get_proteomics()
p['br'] = "mes"
p
# Out:
# Name           A1BG       A2M      AAAS      AACS     AADAT     AAED1  \
# Sample_ID
# S001       0.077630  0.487228 -0.254208 -0.144373  0.551881 -0.025276
# S002      -0.145975  0.798796  0.184242 -0.470603       NaN  0.390211
# S003       0.821991  1.096470 -0.094421 -0.106304  0.084578  0.176402
# S004      -0.064567  0.129385  0.047751 -0.118187  0.237434       NaN
# S005      -0.763691 -1.031834 -0.217194 -0.695701  0.184173 -0.474816
# ...             ...       ...       ...       ...       ...       ...
# S111      -1.624156 -1.163916 -0.570896  0.608478  0.756814       NaN
# S112      -1.452245 -1.147384 -0.373231  0.584371       NaN -1.670928
# S113      -1.902994 -1.162469 -0.411892  0.534934       NaN  0.598046
# S114      -2.003926 -1.605927 -0.694845  0.817702  0.644152 -0.336013
# S115      -1.590282 -1.227305 -0.487413  0.866017  1.033949 -0.355792
#
# Name          AAGAB      AAK1     AAMDC      AAMP  ...    ZSWIM8      ZW10  \
# ...

# %%
a = list(p.columns)
c = p.melt(id_vars = 'br', value_vars = a[:-1])

# %%
c
# Out:
#           br  Name     value
# 0        mes  A1BG  0.077630
# 1        mes  A1BG -0.145975
# 2        mes  A1BG  0.821991
# 3        mes  A1BG -0.064567
# 4        mes  A1BG -0.763691
# ...      ...   ...       ...
# 1214364  mes  ZZZ3 -0.013637
# 1214365  mes  ZZZ3 -0.217014
# 1214366  mes  ZZZ3 -0.419138
# 1214367  mes  ZZZ3 -0.468881
# 1214368  mes  ZZZ3 -0.376205
#
# [1214369 rows x 3 columns]
