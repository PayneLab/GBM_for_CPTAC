# %% [markdown]
# # RB1 and MCM

# %% [markdown]
# ## Step 1: Library Imports

# %% [markdown]
# Run this cell to import the necessary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import re

import cptac
import cptac.utils as u

# %%
def format_pval_annotation(pval_symbol, x1, x2, line_start = .05, line_height=.05):
    # for manual adjustment to pval annotations
    
    y, h = line_start, line_height
    plt.plot([x1, x1, x2, x2], #draw horizontal line
             [y, y+h, y+h, y], #vertical line
             lw=1.5, color= '.3')
    plt.text((x1+x2)*.5, # half between x coord
             y+h, pval_symbol, horizontalalignment='center', verticalalignment='bottom', color = "black")

# %% [markdown]
# ## Step 2: Find the mutation frequency of the gene of interest

# %%
#cptac.download(dataset='ccrcc', version='0.0')
brain = cptac.Gbm()
desired_cutoff = 0.05
gene = 'RB1'

# %% [markdown]
# # Proteomics

# %%
# Step 1 - Create dataframe in order to do comparisons with wrap_ttest  
omics_gene_list = ['MCM2','MCM3','MCM6']
prot_and_mut = brain.join_omics_to_mutations(
    mutations_genes = gene, omics_df_name = 'proteomics', omics_genes = omics_gene_list) # single col level
# Out:
# Warning: In joining the somatic_mutation table, no mutations were found for the following samples, so they were filled with Wildtype_Tumor or Wildtype_Normal: 99 samples for the RB1 gene (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py, line 4)

# %%
# Step 2 - Create the binary column needed to do the comparison
prot_and_mut['RB1_mutation_status'] = prot_and_mut[gene+'_Mutation_Status'].apply(
    lambda x: 'Wildtype' if x == 'Wildtype_Tumor' else 'Mutated')

# Step 3 - Format
mut_wt = prot_and_mut.loc[prot_and_mut['Sample_Status'] == 'Tumor']
columns_to_drop = [gene+"_Mutation", gene+"_Location", gene+"_Mutation_Status", "Sample_Status"]
binary_prot = mut_wt.drop(columns_to_drop, axis = 1)

# %%
# Use al.wrap_ttest for many columns of phospho data (takes phospho sites into account with bonferroni cutoff)
prot_col_list = list(binary_prot.columns).remove('RB1_mutation_status')

# Step 4 - T-test comparing means of mutated vs wildtype effect on cis omics
print("Doing t-test comparison for mutation status")
prot_pval_results = u.wrap_ttest(binary_prot, 'RB1_mutation_status', prot_col_list,verbose=True)
prot_pval_results
# Out:
# Doing t-test comparison for mutation status
# MCM2_proteomics :  0.0004843042653625298
# MCM3_proteomics :  0.0009823912551144478
# MCM6_proteomics :  0.00043663742812360517
# 3 significant comparisons!
#         Comparison   P_Value
# 0  MCM6_proteomics  0.000437
# 1  MCM2_proteomics  0.000484
# 2  MCM3_proteomics  0.000982

# %%
binary_prot_melted = binary_prot.melt(id_vars='RB1_mutation_status')
binary_prot_melted
# Out:
#     RB1_mutation_status             Name     value
# 0               Mutated  MCM2_proteomics  0.865204
# 1               Mutated  MCM2_proteomics  0.943165
# 2              Wildtype  MCM2_proteomics -0.236399
# 3               Mutated  MCM2_proteomics -0.093372
# 4              Wildtype  MCM2_proteomics -0.957693
# ..                  ...              ...       ...
# 292            Wildtype  MCM6_proteomics  0.440672
# 293            Wildtype  MCM6_proteomics  1.348624
# 294            Wildtype  MCM6_proteomics -0.345955
# 295            Wildtype  MCM6_proteomics -0.474821
# 296            Wildtype  MCM6_proteomics  1.113141
#
# [297 rows x 3 columns]

# %%
plt.rcParams['figure.figsize']=(15,10) #size of plot
sns.set(font_scale = 1.3)

boxplot = sns.boxplot(x='Name', y="value", hue = 'RB1_mutation_status', 
                         hue_order = ['Wildtype', 'Mutated'], data = binary_prot_melted, showfliers = False)    
boxplot.set_title("RB1 Mutation Effect on MCM Proteomic Abundance")
boxplot = sns.stripplot(x='Name', y="value", hue = 'RB1_mutation_status', data = binary_prot_melted, jitter = True, 
                           color = ".3", hue_order = ['Wildtype', 'Mutated'], dodge = True)
boxplot.set(xlabel = "\nMCM Proteins", ylabel = 'Proteomics')

#boxplot.set_xticklabels(boxplot.get_xticklabels(),rotation= 80)

# format legend
handles, labels = boxplot.get_legend_handles_labels()
plt.legend(handles[0:2], labels[0:2])

format_pval_annotation('*',-.2, .2, 2)
format_pval_annotation('*',.8, 1.2, 2)
format_pval_annotation('*',1.8, 2.2, 2)

plt.show()
plt.clf()
plt.close()

# %% [markdown]
# # Phosphopoteomics MCM

# %%
phos = brain.join_omics_to_mutations(
    mutations_genes = 'RB1', omics_df_name = 'phosphoproteomics', omics_genes = ['MCM2','MCM3','MCM6'])
flatten_phospho_and_mut = brain.reduce_multiindex(phos, levels_to_drop=['Database_ID'], flatten=True)

# Step 2 - Create the binary column needed to do the comparison
flatten_phospho_and_mut['RB1_mutation_status'] = flatten_phospho_and_mut['RB1_Mutation_Status'].apply(
    lambda x: 'Wildtype' if x == 'Wildtype_Tumor' else('Normal' if x == 'Wildtype_Normal' else 'Mutated'))

# Step 3 - Format
mut_wt = flatten_phospho_and_mut.loc[flatten_phospho_and_mut['Sample_Status'] == 'Tumor'] # drop normal
columns_to_drop = [gene+"_Mutation", gene+"_Location", gene+"_Mutation_Status", "Sample_Status"]
binary_phospho = mut_wt.drop(columns_to_drop, axis = 1)
only_phospho = binary_phospho.drop('RB1_mutation_status', axis = 1)

# keep dataframe formatted to graph with normal samples
phospho_normal = flatten_phospho_and_mut.drop(columns_to_drop, axis = 1) # includes normal samples 
only_phospho
# Out:
# Warning: In joining the somatic_mutation table, no mutations were found for the following samples, so they were filled with Wildtype_Tumor or Wildtype_Normal: 99 samples for the RB1 gene (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py, line 2)
# Name       MCM2_phosphoproteomics_S108_AIPELDAYEAEGLALDDEDVEELTAS*QR  \
# Sample_ID
# S001                                                0.250213
# S002                                                0.680272
# S003                                               -1.100628
# S004                                                     NaN
# S005                                               -1.149843
# ...                                                      ...
# S100                                                     NaN
# S101                                                0.632754
# S102                                               -0.349986
# S104                                                     NaN
# S105                                               -0.185136
#
# Name       MCM2_phosphoproteomics_S108_AIPELDAYEAEGLALDDEDVEELTAS*QREAAER  \
# Sample_ID
# S001                                                0.469123
# S002                                                     NaN
# S003                                                1.074279
# S004                                                0.539857
# S005                                               -1.269670
# ...                                                      ...
# S100                                                     NaN
# S101                                                0.893717
# S102                                               -0.093704
# S104                                                     NaN
# S105                                                0.318148
#
# Name       MCM2_phosphoproteomics_S139_GLLYDS*DEEDEERPAR  \
# Sample_ID
# S001                                            0.553357
# S002                                            0.592142
# S003                                           -0.417157
# S004                                                 NaN
# S005                                           -1.141344
# ...                                                  ...
# S100                                            0.359011
# S101                                            0.691414
# S102                                           -0.576220
# S104                                           -0.786470
# S105                                            0.579851
#
# Name       MCM2_phosphoproteomics_S139_GLLYDS*DEEDEERPARK  \
# Sample_ID
# S001                                             1.007214
# S002                                             1.128073
# S003                                            -0.105052
# S004                                             0.118192
# S005                                            -0.707192
# ...                                                   ...
# S100                                             0.418889
# S101                                             1.109485
# S102                                            -0.328765
# S104                                            -0.328629
# S105                                             1.333506
#
# Name       MCM2_phosphoproteomics_S139_RGLLYDS*DEEDEERPAR  \
# Sample_ID
# S001                                             0.116577
# S002                                                  NaN
# S003                                                  NaN
# S004                                             1.192966
# S005                                            -0.493904
# ...                                                   ...
# S100                                                  NaN
# S101                                             0.900207
# S102                                            -0.119699
# S104                                                  NaN
# S105                                                  NaN
#
# Name       MCM2_phosphoproteomics_S139_RGLLYDS*DEEDEERPARK  \
# Sample_ID
# S001                                                   NaN
# S002                                                   NaN
# S003                                                   NaN
# S004                                                   NaN
# S005                                                   NaN
# ...                                                    ...
# S100                                                   NaN
# S101                                                   NaN
# S102                                                   NaN
# S104                                                   NaN
# S105                                                   NaN
#
# Name       MCM2_phosphoproteomics_S26S27_GNDPLTS*S*PGR  \
# Sample_ID
# S001                                               NaN
# S002                                               NaN
# S003                                               NaN
# S004                                               NaN
# S005                                               NaN
# ...                                                ...
# S100                                         -0.029957
# S101                                               NaN
# S102                                               NaN
# S104                                         -0.323839
# S105                                               NaN
#
# Name       MCM2_phosphoproteomics_S27_GNDPLTSS*PGR  \
# Sample_ID
# S001                                      0.526739
# S002                                           NaN
# S003                                     -0.412701
# S004                                     -0.194149
# S005                                     -0.524123
# ...                                            ...
# S100                                      0.174771
# S101                                      0.609089
# S102                                           NaN
# S104                                     -0.895049
# S105                                           NaN
#
# Name       MCM2_phosphoproteomics_S27_RGNDPLTSS*PGR  \
# Sample_ID
# S001                                            NaN
# S002                                       0.940525
# S003                                      -0.455602
# S004                                      -0.680688
# S005                                            NaN
# ...                                             ...
# S100                                       0.214947
# S101                                            NaN
# S102                                      -0.244054
# S104                                      -0.576091
# S105                                            NaN
#
# Name       MCM2_phosphoproteomics_S27S31_GNDPLTSS*PGRS*SR  ...  \
# Sample_ID                                                  ...
# S001                                                  NaN  ...
# S002                                                  NaN  ...
# S003                                                  NaN  ...
# S004                                                  NaN  ...
# S005                                                  NaN  ...
# ...                                                   ...  ...
# S100                                                  NaN  ...
# S101                                                  NaN  ...
# S102                                                  NaN  ...
# S104                                                  NaN  ...
# S105                                                  NaN  ...
#
# Name       MCM3_phosphoproteomics_T719S726_RSEDESET*EDEEEKS*QEDQEQK  \
# Sample_ID
# S001                                                0.678117
# S002                                                     NaN
# S003                                                     NaN
# S004                                                     NaN
# S005                                               -0.069588
# ...                                                      ...
# S100                                                     NaN
# S101                                                     NaN
# S102                                                     NaN
# S104                                                     NaN
# S105                                                     NaN
#
# Name       MCM3_phosphoproteomics_T758_DGDSYDPYDFSDT*EEEMPQVHTPK  \
# Sample_ID
# S001                                                0.404877
# S002                                                     NaN
# S003                                               -0.544556
# S004                                               -0.870803
# S005                                               -1.647757
# ...                                                      ...
# S100                                                0.365978
# S101                                                     NaN
# S102                                               -0.670114
# S104                                               -0.267414
# S105                                                0.622340
#
# Name       MCM3_phosphoproteomics_T758T767_DGDSYDPYDFSDT*EEEMPQVHT*PK  \
# Sample_ID
# S001                                                0.760381
# S002                                                1.179724
# S003                                                     NaN
# S004                                                0.144140
# S005                                               -0.782928
# ...                                                      ...
# S100                                                0.192255
# S101                                                1.224494
# S102                                               -0.765056
# S104                                               -0.338715
# S105                                                1.175646
#
# Name       MCM3_phosphoproteomics_T767_DGDSYDPYDFSDTEEEMPQVHT*PK  \
# Sample_ID
# S001                                                1.263384
# S002                                                     NaN
# S003                                                0.523043
# S004                                               -0.125183
# S005                                               -0.504335
# ...                                                      ...
# S100                                                     NaN
# S101                                                     NaN
# S102                                                0.084825
# S104                                                     NaN
# S105                                                1.167921
#
# Name       MCM3_phosphoproteomics_Y750T758_DGDSY*DPYDFSDT*EEEMPQVHTPK  \
# Sample_ID
# S001                                               -0.027740
# S002                                                1.487462
# S003                                               -0.490306
# S004                                                     NaN
# S005                                               -1.203474
# ...                                                      ...
# S100                                                1.119711
# S101                                                     NaN
# S102                                               -0.451585
# S104                                               -1.110846
# S105                                                     NaN
#
# Name       MCM3_phosphoproteomics_Y750T758T767_DGDSY*DPYDFSDT*EEEMPQVHT*PK  \
# Sample_ID
# S001                                                0.738357
# S002                                                0.919016
# S003                                               -0.500680
# S004                                                0.060158
# S005                                               -1.139279
# ...                                                      ...
# S100                                               -0.397695
# S101                                                     NaN
# S102                                               -0.461740
# S104                                               -0.530980
# S105                                                     NaN
#
# Name       MCM3_phosphoproteomics_Y753S756_DGDSYDPY*DFS*DTEEEMPQVHTPK  \
# Sample_ID
# S001                                                     NaN
# S002                                                     NaN
# S003                                                     NaN
# S004                                                     NaN
# S005                                                     NaN
# ...                                                      ...
# S100                                                     NaN
# S101                                                     NaN
# S102                                               -0.172133
# S104                                                     NaN
# S105                                                     NaN
#
# Name       MCM3_phosphoproteomics_Y753T758_DGDSYDPY*DFSDT*EEEMPQVHTPK  \
# Sample_ID
# S001                                                     NaN
# S002                                                     NaN
# S003                                                     NaN
# S004                                                     NaN
# S005                                                     NaN
# ...                                                      ...
# S100                                                     NaN
# S101                                                 0.54111
# S102                                                     NaN
# S104                                                     NaN
# S105                                                     NaN
#
# Name       MCM6_phosphoproteomics_S762_EIESEIDS*EEELINK  \
# Sample_ID
# S001                                           1.420706
# S002                                                NaN
# S003                                                NaN
# S004                                                NaN
# S005                                          -0.856215
# ...                                                 ...
# S100                                                NaN
# S101                                          -0.041491
# S102                                          -0.338995
# S104                                                NaN
# S105                                           1.621062
#
# Name       MCM6_phosphoproteomics_S762_EIESEIDS*EEELINKK
# Sample_ID
# S001                                            1.877255
# S002                                            1.948601
# S003                                           -1.433919
# S004                                            1.810520
# S005                                           -0.940915
# ...                                                  ...
# S100                                            0.071564
# S101                                           -0.930436
# S102                                           -0.099489
# S104                                           -1.646106
# S105                                            1.570789
#
# [99 rows x 49 columns]

# %%
# Use al.wrap_ttest for many columns of phospho data (takes phospho sites into account with bonferroni cutoff)
phos_col_list = list(only_phospho.columns)

# Step 4 - T-test comparing means of mutated vs wildtype effect on cis omics
print("Doing t-test comparison for mutation status")
phos_pval_results = u.wrap_ttest(binary_phospho, 'RB1_mutation_status', phos_col_list)
phos_pval_results
# Out:
# Doing t-test comparison for mutation status
# 11 significant comparisons!
# C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\numpy\core\fromnumeric.py:3367: RuntimeWarning: Degrees of freedom <= 0 for slice
#   **kwargs)
# C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\numpy\core\_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\scipy\stats\_distn_infrastructure.py:877: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\scipy\stats\_distn_infrastructure.py:877: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\scipy\stats\_distn_infrastructure.py:1831: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
#                                            Comparison       P_Value
# 0       MCM6_phosphoproteomics_S762_EIESEIDS*EEELINKK  9.811491e-08
# 1   MCM3_phosphoproteomics_S205_RYS*DLTTLVAFPSSSVYPTK  2.610996e-07
# 2   MCM3_phosphoproteomics_S756T758_DGDSYDPYDFS*DT...  2.761099e-05
# 3    MCM3_phosphoproteomics_S717T719_RSEDES*ET*EDEEEK  9.685043e-05
# 4        MCM6_phosphoproteomics_S762_EIESEIDS*EEELINK  9.706725e-05
# 5   MCM3_phosphoproteomics_S713S717T719_KRS*EDES*E...  1.171451e-04
# 6   MCM2_phosphoproteomics_S108_AIPELDAYEAEGLALDDE...  1.244903e-04
# 7       MCM2_phosphoproteomics_S139_GLLYDS*DEEDEERPAR  3.395965e-04
# 8   MCM3_phosphoproteomics_S717T719S726_RSEDES*ET*...  6.866016e-04
# 9      MCM2_phosphoproteomics_S139_GLLYDS*DEEDEERPARK  8.706963e-04
# 10            MCM2_phosphoproteomics_S41_RTDALTSS*PGR  8.977280e-04

# %%
# Create data frame with all significant phospho sites in order to graph
#phospho_list = list(phos_pval_results['Comparison']) # comment when no sig phospho sites
phospho_list = list(only_phospho.columns)

phospho_df_RB1 = pd.melt(binary_phospho, id_vars = 'RB1_mutation_status', 
            value_vars = phospho_list, var_name = 'specific_phospho', value_name = 'phosphoproteomics')
phospho_df_RB1.replace(to_replace = '_phosphoproteomics', value = '', 
                        inplace = True, regex = True) # shorten column names
phospho_df_RB1.replace(to_replace = '_[A-Z]*\*[A-Z]*\*?[A-Z]*\*?[A-Z]*', value = '', 
                        inplace = True, regex = True)

phospho_df_RB1
# Out:
#      RB1_mutation_status specific_phospho  phosphoproteomics
# 0                Mutated        MCM2_S108           0.250213
# 1                Mutated        MCM2_S108           0.680272
# 2               Wildtype        MCM2_S108          -1.100628
# 3                Mutated        MCM2_S108                NaN
# 4               Wildtype        MCM2_S108          -1.149843
# ...                  ...              ...                ...
# 4846            Wildtype        MCM6_S762           0.071564
# 4847            Wildtype        MCM6_S762          -0.930436
# 4848            Wildtype        MCM6_S762          -0.099489
# 4849            Wildtype        MCM6_S762          -1.646106
# 4850            Wildtype        MCM6_S762           1.570789
#
# [4851 rows x 3 columns]

# %%
# Visualize 
plt.rcParams['figure.figsize']=(20,15)#size of plot
sns.set(font_scale = 1.7)

#plt.rcParams['figure.figsize']=(24,16) #size of plot
boxplot = sns.boxplot(x='specific_phospho', y="phosphoproteomics", hue = 'RB1_mutation_status', 
                          hue_order = ['Wildtype', 'Mutated'],
                          order = ['MCM2_S41','MCM2_S108','MCM2_S139','MCM3_S205','MCM3_S756T758','MCM3_S717T719','MCM3_S713S717T719','MCM3_S717T719S726','MCM6_S762'],
                          data = phospho_df_RB1, showfliers = False)    
boxplot.set_title("RB1 Mutation Effect on MCM Phosphoproteomic Abundance")
boxplot = sns.stripplot(x='specific_phospho', y="phosphoproteomics", hue = 'RB1_mutation_status', data = phospho_df_RB1, jitter = True, 
                           color = ".3",dodge = True, hue_order = ['Wildtype', 'Mutated'],
                           order=['MCM2_S41','MCM2_S108','MCM2_S139','MCM3_S205','MCM3_S756T758','MCM3_S717T719','MCM3_S713S717T719','MCM3_S717T719S726','MCM6_S762'])
boxplot.set(xlabel = "\nMCM Significant Phosphosites", ylabel = 'Phosphorylation Levels')

boxplot.set_xticklabels(boxplot.get_xticklabels(),rotation = 80)

# format legend
#handles, labels = boxplot.get_legend_handles_labels()
#plt.legend(handles[0:2], labels[0:2])

plt.show()
plt.clf()
plt.close()

# %% [markdown]
# # Normalize phopho

# %% [markdown]
# Data already is log transformed. To normalize Phosphoproteomics - Proteomics

# %% [markdown]
# MCM2

# %%
prot = brain.get_proteomics()
prot_mut = brain.join_omics_to_mutations(
    mutations_genes = 'RB1', omics_df_name = 'proteomics', omics_genes = 'MCM2')
prot_tumors = prot_mut.loc[prot_mut['Sample_Status'] == 'Tumor']
mprot = prot_tumors[['MCM2_proteomics']]
mprot
# Out:
# Warning: In joining the somatic_mutation table, no mutations were found for the following samples, so they were filled with Wildtype_Tumor or Wildtype_Normal: 99 samples for the RB1 gene (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py, line 3)
# Name       MCM2_proteomics
# Sample_ID
# S001              0.865204
# S002              0.943165
# S003             -0.236399
# S004             -0.093372
# S005             -0.957693
# ...                    ...
# S100              0.322572
# S101              1.145468
# S102             -0.438594
# S104             -0.517491
# S105              0.881857
#
# [99 rows x 1 columns]

# %%
phos = brain.join_omics_to_mutations(
    mutations_genes = 'RB1', omics_df_name = 'phosphoproteomics', omics_genes = 'MCM2')
flatten = brain.reduce_multiindex(phos, levels_to_drop=['Database_ID'], flatten=True)

flatten['RB1_mutation_status'] = flatten['RB1_Mutation_Status'].apply(
    lambda x: 'Wildtype' if x == 'Wildtype_Tumor' else 'Mutated')

tumors = flatten.loc[flatten['Sample_Status'] == 'Tumor'] # drop normal

columns_to_drop = [gene+"_Mutation", gene+"_Location", gene+"_Mutation_Status", "Sample_Status"]
binary_MCM2 = tumors.drop(columns_to_drop, axis = 1)
only_MCM2 = binary_MCM2.drop('RB1_mutation_status', axis = 1)
# Out:
# Warning: In joining the somatic_mutation table, no mutations were found for the following samples, so they were filled with Wildtype_Tumor or Wildtype_Normal: 99 samples for the RB1 gene (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py, line 2)

# %%
norm = pd.DataFrame()

for i, cols in only_MCM2.iteritems():
    norm[i] = cols - mprot['MCM2_proteomics']

MCM2_df = norm.join(binary_MCM2['RB1_mutation_status'])

# %%
MCM2_col_list = list(norm.columns)

# T-test
print("Doing t-test comparison for mutation status of RB1 on MCM2 phosphorylation")
MCM2_phos_pval_results = u.wrap_ttest(MCM2_df, 'RB1_mutation_status', MCM2_col_list)
MCM2_phos_pval_results
# Out:
# Doing t-test comparison for mutation status of RB1 on MCM2 phosphorylation
# No significant comparisons.

# %% [markdown]
# MCM3

# %%
prot = brain.get_proteomics()
prot_mut = brain.join_omics_to_mutations(
    mutations_genes = 'RB1', omics_df_name = 'proteomics', omics_genes = 'MCM3')
prot_tumors = prot_mut.loc[prot_mut['Sample_Status'] == 'Tumor']
mprot = prot_tumors[['MCM3_proteomics']]
mprot
# Out:
# Warning: In joining the somatic_mutation table, no mutations were found for the following samples, so they were filled with Wildtype_Tumor or Wildtype_Normal: 99 samples for the RB1 gene (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py, line 3)
# Name       MCM3_proteomics
# Sample_ID
# S001              1.072049
# S002              0.860945
# S003             -0.133899
# S004             -0.466708
# S005             -0.821546
# ...                    ...
# S100              0.351698
# S101              1.224041
# S102             -0.331383
# S104             -0.455741
# S105              1.201596
#
# [99 rows x 1 columns]

# %%
phos = brain.join_omics_to_mutations(
    mutations_genes = 'RB1', omics_df_name = 'phosphoproteomics', omics_genes = 'MCM3')
flatten = brain.reduce_multiindex(phos, levels_to_drop=['Database_ID'], flatten=True)

flatten['RB1_mutation_status'] = flatten['RB1_Mutation_Status'].apply(
    lambda x: 'Wildtype' if x == 'Wildtype_Tumor' else 'Mutated')

tumors = flatten.loc[flatten['Sample_Status'] == 'Tumor'] # drop normal

columns_to_drop = [gene+"_Mutation", gene+"_Location", gene+"_Mutation_Status", "Sample_Status"]
binary_MCM3 = tumors.drop(columns_to_drop, axis = 1)
only_MCM3 = binary_MCM3.drop('RB1_mutation_status', axis = 1)
binary_MCM3['RB1_mutation_status']
only_MCM3
# Out:
# Warning: In joining the somatic_mutation table, no mutations were found for the following samples, so they were filled with Wildtype_Tumor or Wildtype_Normal: 99 samples for the RB1 gene (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py, line 2)
# Name       MCM3_phosphoproteomics_S205_RYS*DLTTLVAFPSSSVYPTK  \
# Sample_ID
# S001                                                1.078313
# S002                                                0.868698
# S003                                                0.281070
# S004                                               -0.312857
# S005                                               -0.478029
# ...                                                      ...
# S100                                                0.776120
# S101                                                0.776362
# S102                                               -0.153918
# S104                                               -0.350635
# S105                                               -0.110341
#
# Name       MCM3_phosphoproteomics_S713_KRS*EDESETEDEEEK  \
# Sample_ID
# S001                                           1.197712
# S002                                           0.520708
# S003                                           0.230958
# S004                                          -0.403621
# S005                                           1.040704
# ...                                                 ...
# S100                                          -3.360659
# S101                                           0.300378
# S102                                          -0.511331
# S104                                           0.340117
# S105                                           0.805479
#
# Name       MCM3_phosphoproteomics_S713S717_KRS*EDES*ETEDEEEK  \
# Sample_ID
# S001                                                0.636480
# S002                                                0.746420
# S003                                               -0.393435
# S004                                               -0.416728
# S005                                               -0.729764
# ...                                                      ...
# S100                                               -0.567245
# S101                                                1.073278
# S102                                               -0.695425
# S104                                               -0.433514
# S105                                                2.246135
#
# Name       MCM3_phosphoproteomics_S713S717T719_KRS*EDES*ET*EDEEEK  \
# Sample_ID
# S001                                                1.140307
# S002                                                1.587860
# S003                                               -0.710630
# S004                                                0.025458
# S005                                               -1.381473
# ...                                                      ...
# S100                                                0.286548
# S101                                                1.467751
# S102                                               -0.720057
# S104                                               -0.217025
# S105                                                1.387697
#
# Name       MCM3_phosphoproteomics_S713T719_RS*EDESET*EDEEEK  \
# Sample_ID
# S001                                                    NaN
# S002                                                    NaN
# S003                                              -0.369789
# S004                                                    NaN
# S005                                                    NaN
# ...                                                     ...
# S100                                                    NaN
# S101                                                    NaN
# S102                                                    NaN
# S104                                                    NaN
# S105                                                    NaN
#
# Name       MCM3_phosphoproteomics_S713T719S726_RS*EDESET*EDEEEKS*QEDQEQK  \
# Sample_ID
# S001                                                     NaN
# S002                                                     NaN
# S003                                                     NaN
# S004                                                1.676289
# S005                                                     NaN
# ...                                                      ...
# S100                                                     NaN
# S101                                                     NaN
# S102                                                     NaN
# S104                                                     NaN
# S105                                                     NaN
#
# Name       MCM3_phosphoproteomics_S717_KRSEDES*ETEDEEEK  \
# Sample_ID
# S001                                                NaN
# S002                                           0.339036
# S003                                                NaN
# S004                                                NaN
# S005                                                NaN
# ...                                                 ...
# S100                                                NaN
# S101                                                NaN
# S102                                                NaN
# S104                                                NaN
# S105                                                NaN
#
# Name       MCM3_phosphoproteomics_S717_RSEDES*ETEDEEEK  \
# Sample_ID
# S001                                          0.789201
# S002                                          0.394290
# S003                                         -0.503656
# S004                                         -0.611863
# S005                                         -0.283311
# ...                                                ...
# S100                                         -0.096263
# S101                                          0.752803
# S102                                         -0.032070
# S104                                         -0.512428
# S105                                          1.326800
#
# Name       MCM3_phosphoproteomics_S717T719_KRSEDES*ET*EDEEEK  \
# Sample_ID
# S001                                                0.609024
# S002                                                     NaN
# S003                                                     NaN
# S004                                                     NaN
# S005                                               -0.829937
# ...                                                      ...
# S100                                                     NaN
# S101                                                1.506595
# S102                                                     NaN
# S104                                                     NaN
# S105                                                     NaN
#
# Name       MCM3_phosphoproteomics_S717T719_RSEDES*ET*EDEEEK  ...  \
# Sample_ID                                                    ...
# S001                                               0.944351  ...
# S002                                               0.922311  ...
# S003                                              -0.364562  ...
# S004                                              -0.022558  ...
# S005                                              -1.666821  ...
# ...                                                     ...  ...
# S100                                               0.397658  ...
# S101                                               0.871357  ...
# S102                                              -0.353364  ...
# S104                                              -0.731235  ...
# S105                                               0.985679  ...
#
# Name       MCM3_phosphoproteomics_T719_KRSEDESET*EDEEEK  \
# Sample_ID
# S001                                           0.327950
# S002                                                NaN
# S003                                                NaN
# S004                                                NaN
# S005                                          -0.020151
# ...                                                 ...
# S100                                                NaN
# S101                                                NaN
# S102                                                NaN
# S104                                                NaN
# S105                                                NaN
#
# Name       MCM3_phosphoproteomics_T719_RSEDESET*EDEEEK  \
# Sample_ID
# S001                                          1.059769
# S002                                               NaN
# S003                                               NaN
# S004                                         -0.428378
# S005                                         -1.484511
# ...                                                ...
# S100                                               NaN
# S101                                          0.439947
# S102                                         -0.131417
# S104                                               NaN
# S105                                          1.215841
#
# Name       MCM3_phosphoproteomics_T719S726_RSEDESET*EDEEEKS*QEDQEQK  \
# Sample_ID
# S001                                                0.678117
# S002                                                     NaN
# S003                                                     NaN
# S004                                                     NaN
# S005                                               -0.069588
# ...                                                      ...
# S100                                                     NaN
# S101                                                     NaN
# S102                                                     NaN
# S104                                                     NaN
# S105                                                     NaN
#
# Name       MCM3_phosphoproteomics_T758_DGDSYDPYDFSDT*EEEMPQVHTPK  \
# Sample_ID
# S001                                                0.404877
# S002                                                     NaN
# S003                                               -0.544556
# S004                                               -0.870803
# S005                                               -1.647757
# ...                                                      ...
# S100                                                0.365978
# S101                                                     NaN
# S102                                               -0.670114
# S104                                               -0.267414
# S105                                                0.622340
#
# Name       MCM3_phosphoproteomics_T758T767_DGDSYDPYDFSDT*EEEMPQVHT*PK  \
# Sample_ID
# S001                                                0.760381
# S002                                                1.179724
# S003                                                     NaN
# S004                                                0.144140
# S005                                               -0.782928
# ...                                                      ...
# S100                                                0.192255
# S101                                                1.224494
# S102                                               -0.765056
# S104                                               -0.338715
# S105                                                1.175646
#
# Name       MCM3_phosphoproteomics_T767_DGDSYDPYDFSDTEEEMPQVHT*PK  \
# Sample_ID
# S001                                                1.263384
# S002                                                     NaN
# S003                                                0.523043
# S004                                               -0.125183
# S005                                               -0.504335
# ...                                                      ...
# S100                                                     NaN
# S101                                                     NaN
# S102                                                0.084825
# S104                                                     NaN
# S105                                                1.167921
#
# Name       MCM3_phosphoproteomics_Y750T758_DGDSY*DPYDFSDT*EEEMPQVHTPK  \
# Sample_ID
# S001                                               -0.027740
# S002                                                1.487462
# S003                                               -0.490306
# S004                                                     NaN
# S005                                               -1.203474
# ...                                                      ...
# S100                                                1.119711
# S101                                                     NaN
# S102                                               -0.451585
# S104                                               -1.110846
# S105                                                     NaN
#
# Name       MCM3_phosphoproteomics_Y750T758T767_DGDSY*DPYDFSDT*EEEMPQVHT*PK  \
# Sample_ID
# S001                                                0.738357
# S002                                                0.919016
# S003                                               -0.500680
# S004                                                0.060158
# S005                                               -1.139279
# ...                                                      ...
# S100                                               -0.397695
# S101                                                     NaN
# S102                                               -0.461740
# S104                                               -0.530980
# S105                                                     NaN
#
# Name       MCM3_phosphoproteomics_Y753S756_DGDSYDPY*DFS*DTEEEMPQVHTPK  \
# Sample_ID
# S001                                                     NaN
# S002                                                     NaN
# S003                                                     NaN
# S004                                                     NaN
# S005                                                     NaN
# ...                                                      ...
# S100                                                     NaN
# S101                                                     NaN
# S102                                               -0.172133
# S104                                                     NaN
# S105                                                     NaN
#
# Name       MCM3_phosphoproteomics_Y753T758_DGDSYDPY*DFSDT*EEEMPQVHTPK
# Sample_ID
# S001                                                     NaN
# S002                                                     NaN
# S003                                                     NaN
# S004                                                     NaN
# S005                                                     NaN
# ...                                                      ...
# S100                                                     NaN
# S101                                                 0.54111
# S102                                                     NaN
# S104                                                     NaN
# S105                                                     NaN
#
# [99 rows x 29 columns]

# %%
norm = pd.DataFrame()

for i, cols in only_MCM3.iteritems():
    norm[i] = cols - mprot['MCM3_proteomics']

MCM3_df = norm.join(binary_MCM3['RB1_mutation_status']) 
MCM3_df
# Out:
#            MCM3_phosphoproteomics_S205_RYS*DLTTLVAFPSSSVYPTK  \
# Sample_ID
# S001                                                0.006264
# S002                                                0.007753
# S003                                                0.414969
# S004                                                0.153851
# S005                                                0.343518
# ...                                                      ...
# S100                                                0.424422
# S101                                               -0.447680
# S102                                                0.177465
# S104                                                0.105106
# S105                                               -1.311937
#
#            MCM3_phosphoproteomics_S713_KRS*EDESETEDEEEK  \
# Sample_ID
# S001                                           0.125663
# S002                                          -0.340236
# S003                                           0.364858
# S004                                           0.063087
# S005                                           1.862250
# ...                                                 ...
# S100                                          -3.712357
# S101                                          -0.923663
# S102                                          -0.179949
# S104                                           0.795858
# S105                                          -0.396117
#
#            MCM3_phosphoproteomics_S713S717_KRS*EDES*ETEDEEEK  \
# Sample_ID
# S001                                               -0.435570
# S002                                               -0.114525
# S003                                               -0.259536
# S004                                                0.049980
# S005                                                0.091782
# ...                                                      ...
# S100                                               -0.918943
# S101                                               -0.150763
# S102                                               -0.364042
# S104                                                0.022227
# S105                                                1.044539
#
#            MCM3_phosphoproteomics_S713S717T719_KRS*EDES*ET*EDEEEK  \
# Sample_ID
# S001                                                0.068257
# S002                                                0.726916
# S003                                               -0.576731
# S004                                                0.492166
# S005                                               -0.559927
# ...                                                      ...
# S100                                               -0.065150
# S101                                                0.243709
# S102                                               -0.388674
# S104                                                0.238716
# S105                                                0.186101
#
#            MCM3_phosphoproteomics_S713T719_RS*EDESET*EDEEEK  \
# Sample_ID
# S001                                                    NaN
# S002                                                    NaN
# S003                                               -0.23589
# S004                                                    NaN
# S005                                                    NaN
# ...                                                     ...
# S100                                                    NaN
# S101                                                    NaN
# S102                                                    NaN
# S104                                                    NaN
# S105                                                    NaN
#
#            MCM3_phosphoproteomics_S713T719S726_RS*EDESET*EDEEEKS*QEDQEQK  \
# Sample_ID
# S001                                                     NaN
# S002                                                     NaN
# S003                                                     NaN
# S004                                                2.142996
# S005                                                     NaN
# ...                                                      ...
# S100                                                     NaN
# S101                                                     NaN
# S102                                                     NaN
# S104                                                     NaN
# S105                                                     NaN
#
#            MCM3_phosphoproteomics_S717_KRSEDES*ETEDEEEK  \
# Sample_ID
# S001                                                NaN
# S002                                          -0.521909
# S003                                                NaN
# S004                                                NaN
# S005                                                NaN
# ...                                                 ...
# S100                                                NaN
# S101                                                NaN
# S102                                                NaN
# S104                                                NaN
# S105                                                NaN
#
#            MCM3_phosphoproteomics_S717_RSEDES*ETEDEEEK  \
# Sample_ID
# S001                                         -0.282849
# S002                                         -0.466654
# S003                                         -0.369757
# S004                                         -0.145155
# S005                                          0.538235
# ...                                                ...
# S100                                         -0.447961
# S101                                         -0.471238
# S102                                          0.299313
# S104                                         -0.056687
# S105                                          0.125204
#
#            MCM3_phosphoproteomics_S717T719_KRSEDES*ET*EDEEEK  \
# Sample_ID
# S001                                               -0.463026
# S002                                                     NaN
# S003                                                     NaN
# S004                                                     NaN
# S005                                               -0.008390
# ...                                                      ...
# S100                                                     NaN
# S101                                                0.282554
# S102                                                     NaN
# S104                                                     NaN
# S105                                                     NaN
#
#            MCM3_phosphoproteomics_S717T719_RSEDES*ET*EDEEEK  ...  \
# Sample_ID                                                    ...
# S001                                              -0.127698  ...
# S002                                               0.061366  ...
# S003                                              -0.230663  ...
# S004                                               0.444150  ...
# S005                                              -0.845275  ...
# ...                                                     ...  ...
# S100                                               0.045960  ...
# S101                                              -0.352685  ...
# S102                                              -0.021982  ...
# S104                                              -0.275494  ...
# S105                                              -0.215917  ...
#
#            MCM3_phosphoproteomics_T719_RSEDESET*EDEEEK  \
# Sample_ID
# S001                                         -0.012281
# S002                                               NaN
# S003                                               NaN
# S004                                          0.038329
# S005                                         -0.662965
# ...                                                ...
# S100                                               NaN
# S101                                         -0.784094
# S102                                          0.199965
# S104                                               NaN
# S105                                          0.014244
#
#            MCM3_phosphoproteomics_T719S726_RSEDESET*EDEEEKS*QEDQEQK  \
# Sample_ID
# S001                                               -0.393932
# S002                                                     NaN
# S003                                                     NaN
# S004                                                     NaN
# S005                                                0.751958
# ...                                                      ...
# S100                                                     NaN
# S101                                                     NaN
# S102                                                     NaN
# S104                                                     NaN
# S105                                                     NaN
#
#            MCM3_phosphoproteomics_T758_DGDSYDPYDFSDT*EEEMPQVHTPK  \
# Sample_ID
# S001                                               -0.667173
# S002                                                     NaN
# S003                                               -0.410657
# S004                                               -0.404095
# S005                                               -0.826211
# ...                                                      ...
# S100                                                0.014280
# S101                                                     NaN
# S102                                               -0.338732
# S104                                                0.188327
# S105                                               -0.579256
#
#            MCM3_phosphoproteomics_T758T767_DGDSYDPYDFSDT*EEEMPQVHT*PK  \
# Sample_ID
# S001                                               -0.311668
# S002                                                0.318780
# S003                                                     NaN
# S004                                                0.610847
# S005                                                0.038618
# ...                                                      ...
# S100                                               -0.159443
# S101                                                0.000452
# S102                                               -0.433674
# S104                                                0.117026
# S105                                               -0.025950
#
#            MCM3_phosphoproteomics_T767_DGDSYDPYDFSDTEEEMPQVHT*PK  \
# Sample_ID
# S001                                                0.191334
# S002                                                     NaN
# S003                                                0.656942
# S004                                                0.341525
# S005                                                0.317211
# ...                                                      ...
# S100                                                     NaN
# S101                                                     NaN
# S102                                                0.416208
# S104                                                     NaN
# S105                                               -0.033675
#
#            MCM3_phosphoproteomics_Y750T758_DGDSY*DPYDFSDT*EEEMPQVHTPK  \
# Sample_ID
# S001                                               -1.099790
# S002                                                0.626517
# S003                                               -0.356407
# S004                                                     NaN
# S005                                               -0.381928
# ...                                                      ...
# S100                                                0.768013
# S101                                                     NaN
# S102                                               -0.120202
# S104                                               -0.655105
# S105                                                     NaN
#
#            MCM3_phosphoproteomics_Y750T758T767_DGDSY*DPYDFSDT*EEEMPQVHT*PK  \
# Sample_ID
# S001                                               -0.333692
# S002                                                0.058071
# S003                                               -0.366780
# S004                                                0.526866
# S005                                               -0.317733
# ...                                                      ...
# S100                                               -0.749393
# S101                                                     NaN
# S102                                               -0.130357
# S104                                               -0.075239
# S105                                                     NaN
#
#            MCM3_phosphoproteomics_Y753S756_DGDSYDPY*DFS*DTEEEMPQVHTPK  \
# Sample_ID
# S001                                                     NaN
# S002                                                     NaN
# S003                                                     NaN
# S004                                                     NaN
# S005                                                     NaN
# ...                                                      ...
# S100                                                     NaN
# S101                                                     NaN
# S102                                                0.159249
# S104                                                     NaN
# S105                                                     NaN
#
#            MCM3_phosphoproteomics_Y753T758_DGDSYDPY*DFSDT*EEEMPQVHTPK  \
# Sample_ID
# S001                                                     NaN
# S002                                                     NaN
# S003                                                     NaN
# S004                                                     NaN
# S005                                                     NaN
# ...                                                      ...
# S100                                                     NaN
# S101                                               -0.682931
# S102                                                     NaN
# S104                                                     NaN
# S105                                                     NaN
#
#            RB1_mutation_status
# Sample_ID
# S001                   Mutated
# S002                   Mutated
# S003                  Wildtype
# S004                   Mutated
# S005                  Wildtype
# ...                        ...
# S100                  Wildtype
# S101                  Wildtype
# S102                  Wildtype
# S104                  Wildtype
# S105                  Wildtype
#
# [99 rows x 30 columns]

# %%
MCM3_col_list = list(norm.columns)

# T-test
print("Doing t-test comparison for mutation status of RB1 on MCM3 phosphorylation")
MCM3_phos_pval_results = u.wrap_ttest(MCM3_df, 'RB1_mutation_status', MCM3_col_list)
MCM3_phos_pval_results
# Out:
# Doing t-test comparison for mutation status of RB1 on MCM3 phosphorylation
# No significant comparisons.

# %% [markdown]
# MCM6

# %%
prot = brain.get_proteomics()
prot_mut = brain.join_omics_to_mutations(
    mutations_genes = 'RB1', omics_df_name = 'proteomics', omics_genes = 'MCM6')
prot_tumors = prot_mut.loc[prot_mut['Sample_Status'] == 'Tumor']
mprot = prot_tumors[['MCM6_proteomics']]
mprot
# Out:
# Warning: In joining the somatic_mutation table, no mutations were found for the following samples, so they were filled with Wildtype_Tumor or Wildtype_Normal: 99 samples for the RB1 gene (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py, line 3)
# Name       MCM6_proteomics
# Sample_ID
# S001              0.929678
# S002              0.934636
# S003              0.127075
# S004             -0.167996
# S005             -0.828283
# ...                    ...
# S100              0.440672
# S101              1.348624
# S102             -0.345955
# S104             -0.474821
# S105              1.113141
#
# [99 rows x 1 columns]

# %%
phos = brain.join_omics_to_mutations(
    mutations_genes = 'RB1', omics_df_name = 'phosphoproteomics', omics_genes = 'MCM6')
flatten = brain.reduce_multiindex(phos, levels_to_drop=['Database_ID'], flatten=True)

flatten['RB1_mutation_status'] = flatten['RB1_Mutation_Status'].apply(
    lambda x: 'Wildtype' if x == 'Wildtype_Tumor' else 'Mutated')

tumors = flatten.loc[flatten['Sample_Status'] == 'Tumor'] # drop normal

columns_to_drop = [gene+"_Mutation", gene+"_Location", gene+"_Mutation_Status", "Sample_Status"]
binary_MCM6 = tumors.drop(columns_to_drop, axis = 1)
only_MCM6 = binary_MCM6.drop('RB1_mutation_status', axis = 1)
binary_MCM6['RB1_mutation_status']
only_MCM6
# Out:
# Warning: In joining the somatic_mutation table, no mutations were found for the following samples, so they were filled with Wildtype_Tumor or Wildtype_Normal: 99 samples for the RB1 gene (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py, line 2)
# Name       MCM6_phosphoproteomics_S762_EIESEIDS*EEELINK  \
# Sample_ID
# S001                                           1.420706
# S002                                                NaN
# S003                                                NaN
# S004                                                NaN
# S005                                          -0.856215
# ...                                                 ...
# S100                                                NaN
# S101                                          -0.041491
# S102                                          -0.338995
# S104                                                NaN
# S105                                           1.621062
#
# Name       MCM6_phosphoproteomics_S762_EIESEIDS*EEELINKK
# Sample_ID
# S001                                            1.877255
# S002                                            1.948601
# S003                                           -1.433919
# S004                                            1.810520
# S005                                           -0.940915
# ...                                                  ...
# S100                                            0.071564
# S101                                           -0.930436
# S102                                           -0.099489
# S104                                           -1.646106
# S105                                            1.570789
#
# [99 rows x 2 columns]

# %%
norm = pd.DataFrame()

for i, cols in only_MCM6.iteritems():
    norm[i] = cols - mprot['MCM6_proteomics']

MCM6_df = norm.join(binary_MCM6['RB1_mutation_status']) 
MCM6_df
# Out:
#            MCM6_phosphoproteomics_S762_EIESEIDS*EEELINK  \
# Sample_ID
# S001                                           0.491029
# S002                                                NaN
# S003                                                NaN
# S004                                                NaN
# S005                                          -0.027932
# ...                                                 ...
# S100                                                NaN
# S101                                          -1.390115
# S102                                           0.006960
# S104                                                NaN
# S105                                           0.507920
#
#            MCM6_phosphoproteomics_S762_EIESEIDS*EEELINKK RB1_mutation_status
# Sample_ID
# S001                                            0.947577             Mutated
# S002                                            1.013964             Mutated
# S003                                           -1.560994            Wildtype
# S004                                            1.978517             Mutated
# S005                                           -0.112632            Wildtype
# ...                                                  ...                 ...
# S100                                           -0.369108            Wildtype
# S101                                           -2.279061            Wildtype
# S102                                            0.246466            Wildtype
# S104                                           -1.171285            Wildtype
# S105                                            0.457648            Wildtype
#
# [99 rows x 3 columns]

# %%
MCM6_col_list = list(norm.columns)

# T-test
print("Doing t-test comparison for mutation status of RB1 on MCM6 phosphorylation")
MCM6_phos_pval_results = u.wrap_ttest(MCM6_df, 'RB1_mutation_status', MCM6_col_list)
MCM6_phos_pval_results
# Out:
# Doing t-test comparison for mutation status of RB1 on MCM6 phosphorylation
# 1 significant comparisons!
#                                       Comparison  P_Value
# 0  MCM6_phosphoproteomics_S762_EIESEIDS*EEELINKK  0.00002

# %%
sig = list(MCM6_phos_pval_results['Comparison'])
mcm = MCM6_df[sig].join(binary_MCM6['RB1_mutation_status'])
d = {'MCM6_phosphoproteomics_S762_EIESEIDS*EEELINKK': "MCM6_S762"}
mcm = mcm.rename(columns = d)
mcm
# Out:
#            MCM6_S762 RB1_mutation_status
# Sample_ID
# S001        0.947577             Mutated
# S002        1.013964             Mutated
# S003       -1.560994            Wildtype
# S004        1.978517             Mutated
# S005       -0.112632            Wildtype
# ...              ...                 ...
# S100       -0.369108            Wildtype
# S101       -2.279061            Wildtype
# S102        0.246466            Wildtype
# S104       -1.171285            Wildtype
# S105        0.457648            Wildtype
#
# [99 rows x 2 columns]

# %%
# Visualize NORMALIZED
plt.rcParams['figure.figsize']=(8,5) #size of plot
sns.set(font_scale = 1.2)

boxplot = sns.boxplot(x='RB1_mutation_status', y="MCM6_S762",
                         order = ['Wildtype', 'Mutated'], data = mcm, showfliers = False)    
boxplot.set_title("RB1 Mutation Type Effect on MCM6 Normalized Phosphoproteomic Abundance")
boxplot = sns.stripplot(x='RB1_mutation_status', y="MCM6_S762", data = mcm, jitter = True, 
                           color = ".1", order = ['Wildtype', 'Mutated'], dodge = True)
boxplot.set(xlabel = "MCM6_S762", ylabel = 'Normalized Phosphorylation Levels')

#boxplot.set_xticklabels(boxplot.get_xticklabels(),rotation = 80)

# format legend
handles, labels = boxplot.get_legend_handles_labels()
plt.legend(handles[0:2], labels[0:2])

format_pval_annotation('*',0, 1, 2.5)

plt.show()
plt.clf()
plt.close()

# %%
# create csv file
mcm = mcm.reset_index()
mcm['Gene'] = 'MCM6'
d = {'Sample_ID': "Sample", 
     'MCM6_S762': "Value",
    'RB1_mutation_status':"Status"}
#mcm = mcm.rename(columns = d)
#mcm.to_csv("MCM6.csv")

# %%
# Create data frame with all significant phospho sites in order to graph
phospho_list = list(phos_pval_results['Comparison']) # comment when no sig phospho sites
MCM = only_MCM2.join(only_MCM3)
MCM = MCM.join(only_MCM6)
sig_mcm = MCM[phospho_list]
norm_mcm236 = sig_mcm.join(binary_MCM6['RB1_mutation_status']) 
norm_mcm236
# Out:
#            MCM6_phosphoproteomics_S762_EIESEIDS*EEELINKK  \
# Sample_ID
# S001                                            1.877255
# S002                                            1.948601
# S003                                           -1.433919
# S004                                            1.810520
# S005                                           -0.940915
# ...                                                  ...
# S100                                            0.071564
# S101                                           -0.930436
# S102                                           -0.099489
# S104                                           -1.646106
# S105                                            1.570789
#
#            MCM3_phosphoproteomics_S205_RYS*DLTTLVAFPSSSVYPTK  \
# Sample_ID
# S001                                                1.078313
# S002                                                0.868698
# S003                                                0.281070
# S004                                               -0.312857
# S005                                               -0.478029
# ...                                                      ...
# S100                                                0.776120
# S101                                                0.776362
# S102                                               -0.153918
# S104                                               -0.350635
# S105                                               -0.110341
#
#            MCM3_phosphoproteomics_S756T758_DGDSYDPYDFS*DT*EEEMPQVHTPK  \
# Sample_ID
# S001                                                0.684861
# S002                                                1.457243
# S003                                               -0.479770
# S004                                               -0.431184
# S005                                               -1.296809
# ...                                                      ...
# S100                                               -0.004296
# S101                                                0.941957
# S102                                               -0.466632
# S104                                               -0.450312
# S105                                                0.454160
#
#            MCM3_phosphoproteomics_S717T719_RSEDES*ET*EDEEEK  \
# Sample_ID
# S001                                               0.944351
# S002                                               0.922311
# S003                                              -0.364562
# S004                                              -0.022558
# S005                                              -1.666821
# ...                                                     ...
# S100                                               0.397658
# S101                                               0.871357
# S102                                              -0.353364
# S104                                              -0.731235
# S105                                               0.985679
#
#            MCM6_phosphoproteomics_S762_EIESEIDS*EEELINK  \
# Sample_ID
# S001                                           1.420706
# S002                                                NaN
# S003                                                NaN
# S004                                                NaN
# S005                                          -0.856215
# ...                                                 ...
# S100                                                NaN
# S101                                          -0.041491
# S102                                          -0.338995
# S104                                                NaN
# S105                                           1.621062
#
#            MCM3_phosphoproteomics_S713S717T719_KRS*EDES*ET*EDEEEK  \
# Sample_ID
# S001                                                1.140307
# S002                                                1.587860
# S003                                               -0.710630
# S004                                                0.025458
# S005                                               -1.381473
# ...                                                      ...
# S100                                                0.286548
# S101                                                1.467751
# S102                                               -0.720057
# S104                                               -0.217025
# S105                                                1.387697
#
#            MCM2_phosphoproteomics_S108_AIPELDAYEAEGLALDDEDVEELTAS*QR  \
# Sample_ID
# S001                                                0.250213
# S002                                                0.680272
# S003                                               -1.100628
# S004                                                     NaN
# S005                                               -1.149843
# ...                                                      ...
# S100                                                     NaN
# S101                                                0.632754
# S102                                               -0.349986
# S104                                                     NaN
# S105                                               -0.185136
#
#            MCM2_phosphoproteomics_S139_GLLYDS*DEEDEERPAR  \
# Sample_ID
# S001                                            0.553357
# S002                                            0.592142
# S003                                           -0.417157
# S004                                                 NaN
# S005                                           -1.141344
# ...                                                  ...
# S100                                            0.359011
# S101                                            0.691414
# S102                                           -0.576220
# S104                                           -0.786470
# S105                                            0.579851
#
#            MCM3_phosphoproteomics_S717T719S726_RSEDES*ET*EDEEEKS*QEDQEQK  \
# Sample_ID
# S001                                                     NaN
# S002                                                3.511724
# S003                                                     NaN
# S004                                                     NaN
# S005                                                     NaN
# ...                                                      ...
# S100                                                     NaN
# S101                                                     NaN
# S102                                               -2.046737
# S104                                                     NaN
# S105                                                0.333402
#
#            MCM2_phosphoproteomics_S139_GLLYDS*DEEDEERPARK  \
# Sample_ID
# S001                                             1.007214
# S002                                             1.128073
# S003                                            -0.105052
# S004                                             0.118192
# S005                                            -0.707192
# ...                                                   ...
# S100                                             0.418889
# S101                                             1.109485
# S102                                            -0.328765
# S104                                            -0.328629
# S105                                             1.333506
#
#            MCM2_phosphoproteomics_S41_RTDALTSS*PGR RB1_mutation_status
# Sample_ID
# S001                                           NaN             Mutated
# S002                                      1.212528             Mutated
# S003                                     -0.108264            Wildtype
# S004                                           NaN             Mutated
# S005                                           NaN            Wildtype
# ...                                            ...                 ...
# S100                                           NaN            Wildtype
# S101                                      0.752360            Wildtype
# S102                                           NaN            Wildtype
# S104                                           NaN            Wildtype
# S105                                           NaN            Wildtype
#
# [99 rows x 12 columns]

# %%
phospho_df_MCM = pd.melt(norm_mcm236, id_vars = 'RB1_mutation_status', 
            value_vars = phospho_list, var_name = 'specific_phospho', value_name = 'phosphoproteomics')
phospho_df_MCM.replace(to_replace = '_phosphoproteomics', value = '', 
                        inplace = True, regex = True) # shorten column names
phospho_df_MCM.replace(to_replace = '_[A-Z]*\*[A-Z]*\*?[A-Z]*\*?[A-Z]*', value = '', 
                        inplace = True, regex = True)

phospho_df_MCM
# Out:
#      RB1_mutation_status specific_phospho  phosphoproteomics
# 0                Mutated        MCM6_S762           1.877255
# 1                Mutated        MCM6_S762           1.948601
# 2               Wildtype        MCM6_S762          -1.433919
# 3                Mutated        MCM6_S762           1.810520
# 4               Wildtype        MCM6_S762          -0.940915
# ...                  ...              ...                ...
# 1084            Wildtype         MCM2_S41                NaN
# 1085            Wildtype         MCM2_S41           0.752360
# 1086            Wildtype         MCM2_S41                NaN
# 1087            Wildtype         MCM2_S41                NaN
# 1088            Wildtype         MCM2_S41                NaN
#
# [1089 rows x 3 columns]

# %%
# Visualize NORMALIZED
plt.rcParams['figure.figsize']=(15,8) #size of plot
sns.set(font_scale = 1.3)

boxplot = sns.boxplot(x='specific_phospho', y="phosphoproteomics", hue = 'RB1_mutation_status', 
                         hue_order = ['Wildtype', 'Mutated'], data = phospho_df_MCM, showfliers = False)    
boxplot.set_title("RB1 Mutation Type effect on Normalized Phosphoproteomic Abundance")
boxplot = sns.stripplot(x='specific_phospho', y="phosphoproteomics", hue = 'RB1_mutation_status', data = phospho_df_MCM, jitter = True, 
                           color = ".3", hue_order = ['Wildtype', 'Mutated'], dodge = True)
boxplot.set(xlabel = "\nMCM Proteins", ylabel = 'Phosphoproteomics')

boxplot.set_xticklabels(boxplot.get_xticklabels(),rotation = 80)

# format legend
handles, labels = boxplot.get_legend_handles_labels()
plt.legend(handles[0:2], labels[0:2])

plt.show()
plt.clf()
plt.close()

# %%
d = {'MCM6_phosphoproteomics_S762_EIESEIDS*EEELINKK': "MCM6_S762", 
     'MCM6_phosphoproteomics_S762_EIESEIDS*EEELINK': "MCM6_S762 2!",
     'MCM3_phosphoproteomics_S205_RYS*DLTTLVAFPSSSVYPTK': "MCM3_S205",
     'MCM3_phosphoproteomics_S756T758_DGDSYDPYDFS*DT*EEEMPQVHTPK': "MCM3_S756T758",
     'MCM3_phosphoproteomics_S717T719_RSEDES*ET*EDEEEK': "MCM3_S717T719",
     'MCM3_phosphoproteomics_S713S717T719_KRS*EDES*ET*EDEEEK': "MCM3_S713S717T719",
     'MCM3_phosphoproteomics_S717T719S726_RSEDES*ET*EDEEEKS*QEDQEQK': "MCM3_S717T719S726",
     'MCM2_phosphoproteomics_S108_AIPELDAYEAEGLALDDEDVEELTAS*QR': "MCM2_S108",
     'MCM2_phosphoproteomics_S139_GLLYDS*DEEDEERPAR': "MCM2_S139",
     'MCM2_phosphoproteomics_S139_GLLYDS*DEEDEERPARK': "MCM2_S139 2!",
     'MCM2_phosphoproteomics_S41_RTDALTSS*PGR': "MCM2_S41"}
sig2 = sig.rename(columns = d)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-b45c3aa248e7> in <module>
#      10      'MCM2_phosphoproteomics_S139_GLLYDS*DEEDEERPARK': "MCM2_S139 2!",
#      11      'MCM2_phosphoproteomics_S41_RTDALTSS*PGR': "MCM2_S41"}
# ---> 12 sig2 = sig.rename(columns = d)
#
# AttributeError: 'list' object has no attribute 'rename'
