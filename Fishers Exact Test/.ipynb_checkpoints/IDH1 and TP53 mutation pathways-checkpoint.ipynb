# %% [markdown]
# # Fishers test for RB1 and TP53 mutation pathways

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats
import cptac
import cptac.utils as u

# %%
gb = cptac.Gbm()

# %%
#get RB1 mutations and drop normal samples
RB1_mutations = gb.join_omics_to_mutations(omics_genes=['IDH1'], omics_df_name='proteomics', mutations_genes=['IDH1'])[['IDH1_Mutation_Status','IDH1_Mutation']]
RB1_mutations = RB1_mutations.loc[RB1_mutations['IDH1_Mutation_Status'] != 'Wildtype_Normal']
#Get EGFR Mutations and drop normal samples
other_gene = 'TP53'
other_col1 = '%s_Mutation_Status'%other_gene
other_col2 = '%s_Mutation'%other_gene
other_mutations = gb.join_omics_to_mutations(omics_genes=[other_gene], omics_df_name='proteomics', mutations_genes=[other_gene])[[other_col1,other_col2]]
other_mutations = other_mutations.loc[other_mutations[other_col1] != 'Wildtype_Normal']
# Out:
# Warning: In joining the somatic_mutation table, no mutations were found for the following samples, so they were filled with Wildtype_Tumor or Wildtype_Normal: 101 samples for the IDH1 gene (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py, line 2)
# Warning: In joining the somatic_mutation table, no mutations were found for the following samples, so they were filled with Wildtype_Tumor or Wildtype_Normal: 77 samples for the TP53 gene (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py, line 8)

# %%
#Concatenate Dataframes
RB1_and_other_Mutations = pd.concat([other_mutations, RB1_mutations], axis=1)[[other_col1,'IDH1_Mutation_Status']]
#Classify all mutations as 'mutation' and all wildtypes as 'wildtype'
RB1_and_other_Mutations = RB1_and_other_Mutations.replace({'Wildtype_Tumor':'Wildtype','Single_mutation':'Mutation','Multiple_mutation':'Mutation'})
RB1_and_other_Mutations.groupby(other_col1).count()
RB1_and_other_Mutations
# Out:
# Name      TP53_Mutation_Status IDH1_Mutation_Status
# Sample_ID
# S001                  Mutation             Wildtype
# S002                  Mutation             Wildtype
# S003                  Wildtype             Wildtype
# S004                  Mutation             Wildtype
# S005                  Wildtype             Wildtype
# ...                        ...                  ...
# S100                  Wildtype             Wildtype
# S101                  Wildtype             Wildtype
# S102                  Wildtype             Wildtype
# S104                  Wildtype             Wildtype
# S105                  Mutation             Wildtype
#
# [99 rows x 2 columns]

# %%
mutations = gb.join_omics_to_mutations(omics_genes=['TP53'], omics_df_name='proteomics', mutations_genes=['RB1','TP53'])
DF1 = mutations.loc[mutations['TP53_Mutation_Status'] != "Wildtype_Tumor"]
DF2 = DF1.loc[DF1['RB1_Mutation_Status'] != "Wildtype_Tumor"]
DF2[:8]
# Out:
# Warning: In joining the somatic_mutation table, no mutations were found for the following samples, so they were filled with Wildtype_Tumor or Wildtype_Normal: 99 samples for the RB1 gene, 77 samples for the TP53 gene (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py, line 1)
# Name       TP53_proteomics                  RB1_Mutation  \
# Sample_ID
# S001              0.044573                 [Splice_Site]
# S002              0.117856             [Frame_Shift_Del]
# S004              1.832557  [Splice_Region, Splice_Site]
# S041              0.889381                 [Splice_Site]
# S068              0.547468           [Nonsense_Mutation]
# S092                   NaN           [Nonsense_Mutation]
# S094              1.222346             [Frame_Shift_Del]
# S099                   NaN             [Frame_Shift_Del]
#
# Name                   RB1_Location RB1_Mutation_Status  \
# Sample_ID
# S001                [p.X654_splice]     Single_mutation
# S002                  [p.F117Lfs*8]     Single_mutation
# S004       [p.D349=, p.X605_splice]   Multiple_mutation
# S041                [p.X500_splice]     Single_mutation
# S068                      [p.R358*]     Single_mutation
# S092                      [p.R552*]     Single_mutation
# S094                  [p.N505Sfs*2]     Single_mutation
# S099                 [p.I680Sfs*16]     Single_mutation
#
# Name                                TP53_Mutation       TP53_Location  \
# Sample_ID
# S001                          [Missense_Mutation]           [p.G266R]
# S002                          [Missense_Mutation]           [p.K132R]
# S004       [Missense_Mutation, Missense_Mutation]  [p.R248Q, p.R158H]
# S041                          [Missense_Mutation]           [p.R175H]
# S068                          [Missense_Mutation]           [p.G266E]
# S092                          [Missense_Mutation]           [p.R175H]
# S094                          [Missense_Mutation]           [p.R175H]
# S099                            [Frame_Shift_Ins]      [p.P191Sfs*18]
#
# Name      TP53_Mutation_Status Sample_Status
# Sample_ID
# S001           Single_mutation         Tumor
# S002           Single_mutation         Tumor
# S004         Multiple_mutation         Tumor
# S041           Single_mutation         Tumor
# S068           Single_mutation         Tumor
# S092           Single_mutation         Tumor
# S094           Single_mutation         Tumor
# S099           Single_mutation         Tumor

# %%
other_exclusive = '%s_Only'%other_gene
for ind, row in RB1_and_other_Mutations.iterrows():
    if row['IDH1_Mutation_Status'] == 'Mutation' and row[other_col1] == 'Mutation':
        RB1_and_other_Mutations.loc[ind, 'Mutation_Exclusivity'] = 'Both'
        
    elif row['IDH1_Mutation_Status'] == 'Mutation' and row[other_col1] != 'Mutation':
        RB1_and_other_Mutations.loc[ind, 'Mutation_Exclusivity'] = 'IDH1_Only'
        
    elif row['IDH1_Mutation_Status'] != 'Mutation' and row[other_col1] == 'Mutation':
        RB1_and_other_Mutations.loc[ind, 'Mutation_Exclusivity'] = other_exclusive
        
    else:
        RB1_and_other_Mutations.loc[ind, 'Mutation_Exclusivity'] = 'Neither'

# %%
#len(RB1_and_other_Mutations.loc[RB1_and_other_Mutations['IDH1_Mutation_Status'] != 'Mutation'])
RB1_and_other_Mutations['Mutation_Exclusivity'].value_counts()
# Out:
# Neither      65
# TP53_Only    26
# Both          6
# IDH1_Only     2
# Name: Mutation_Exclusivity, dtype: int64

# %%
sns.countplot(data=RB1_and_other_Mutations, x='Mutation_Exclusivity')

# %%
RB1_only = RB1_and_other_Mutations.loc[RB1_and_other_Mutations['Mutation_Exclusivity'] == 'RB1_Only']
other_only = RB1_and_other_Mutations.loc[RB1_and_other_Mutations['Mutation_Exclusivity'] == other_exclusive]
Neither = RB1_and_other_Mutations.loc[RB1_and_other_Mutations['Mutation_Exclusivity'] == 'Neither']
Both = RB1_and_other_Mutations.loc[RB1_and_other_Mutations['Mutation_Exclusivity'] == 'Both']
print("RB1 Only: ", len(RB1_only))
print("%s Only: "%other_gene, len(other_only))
print("Neither: ", len(Neither))
print("Both: ", len(Both))
oddsratio, pval = scipy.stats.fisher_exact([[len(Both), len(other_only)],[len(RB1_only), len(Neither)]], alternative='less')
print("pval: ",pval)
RB1_only
# Out:
# RB1 Only:  0
# TP53 Only:  26
# Neither:  65
# Both:  6
# pval:  1.0
# Empty DataFrame
# Columns: [TP53_Mutation_Status, IDH1_Mutation_Status, Mutation_Exclusivity]
# Index: []

# %% [markdown]
# Null H: no association for RB1 and TP53 mutation pathways
#
#
# Alternate hypothesis: RB1 and TP53 muation pathways are associated
#
# Because the p-value is not significant, we don't reject the null hypothesis (that there is no association with RB1 and TP53 mutation pathways).

# %% [markdown]
# A significant p-value means that there is an association.
# "The sum of P-values less than or equal to P_(cutoff)=0.0238 is then 0.0476 which, because it is less than 0.05, is significant. Therefore, in this case, there would be a statistically significant association between the journal and type of article appearing"
# http://mathworld.wolfram.com/FishersExactTest.html
#
# This value can be interpreted as the sum of evidence provided by the observed data—or any more extreme table—for the null hypothesis (that there is no difference in the proportions of studiers between men and women). The smaller the value of p, the greater the evidence for rejecting the null hypothesis; so here the evidence is strong that men and women are not equally likely to be studiers.
# https://en.wikipedia.org/wiki/Fisher%27s_exact_test

# %%
# Check counts

# %%
# Check RB1_only
RB1_mutations = gb.join_omics_to_mutations(omics_genes=['RB1'], omics_df_name='proteomics', mutations_genes=['RB1'])
RB1_mutations = RB1_mutations.loc[RB1_mutations['RB1_Mutation_Status'] != 'Wildtype_Normal']
# Out:
# Warning: In joining the somatic_mutation table, no mutations were found for the following samples, so they were filled with Wildtype_Tumor or Wildtype_Normal: 99 samples for the RB1 gene (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py, line 1)

# %%
RB1_mutations.to_excel('check_rb1.xlsx', sheet_name='Sheet1')

# %%
# check TP53_only
TP53_mutations = gb.join_omics_to_mutations(omics_genes=['TP53'], omics_df_name='proteomics', mutations_genes=['TP53'])
TP53_mutations = TP53_mutations.loc[TP53_mutations['TP53_Mutation_Status'] != 'Wildtype_Normal']
# Out:
# Warning: In joining the somatic_mutation table, no mutations were found for the following samples, so they were filled with Wildtype_Tumor or Wildtype_Normal: 77 samples for the TP53 gene (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py, line 2)

# %%
TP53_mutations.to_excel('check_tp53.xlsx', sheet_name='Sheet1')

# %%
# check Both and Neither
mutations = gb.join_omics_to_mutations(omics_genes=['RB1','TP53'], omics_df_name='proteomics', mutations_genes=['TP53','RB1'])
mutations = mutations.loc[mutations['RB1_Mutation_Status'] != 'Wildtype_Normal']
both_mutations = mutations.loc[mutations['TP53_Mutation_Status'] != 'Wildtype_Normal']
# Out:
# Warning: In joining the somatic_mutation table, no mutations were found for the following samples, so they were filled with Wildtype_Tumor or Wildtype_Normal: 77 samples for the TP53 gene, 99 samples for the RB1 gene (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py, line 2)

# %%
both_mutations.to_excel('check_both.xlsx', sheet_name='Sheet1')

# %%
m = u.get_frequently_mutated(gb,.01)
m.loc[m['Gene']== 'PDGFRA']
# Out:
# Warning: In joining the somatic_mutation table, no mutations were found for the following samples, so they were filled with Wildtype_Tumor or Wildtype_Normal: 77 samples for the TP53 gene (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\cptac\utils\__init__.py, line 388)
# Name    Gene  Unique_Samples_Mut  Missense_Mut  Truncation_Mut  Non-Coding
# 2192  PDGFRA            0.030303      0.030303             0.0         0.0

# %%
m = u.get_frequently_mutated(gb,.05)
# Out:
# Warning: In joining the somatic_mutation table, no mutations were found for the following samples, so they were filled with Wildtype_Tumor or Wildtype_Normal: 77 samples for the TP53 gene (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\cptac\utils\__init__.py, line 388)

# %%
m
# Out:
# Name     Gene  Unique_Samples_Mut  Missense_Mut  Truncation_Mut  Non-Coding
# 0     ARHGAP5            0.060606      0.050505        0.030303    0.000000
# 1      ATP10A            0.050505      0.050505        0.000000    0.000000
# 2       ATP4A            0.050505      0.050505        0.000000    0.000000
# 3        ATRX            0.090909      0.020202        0.070707    0.000000
# 4        BRAF            0.060606      0.060606        0.000000    0.000000
# 5       CSMD3            0.050505      0.050505        0.000000    0.000000
# 6       DOCK6            0.060606      0.050505        0.010101    0.000000
# 7        DSG4            0.050505      0.050505        0.000000    0.000000
# 8        EGFR            0.161616      0.161616        0.000000    0.000000
# 9       EPHA6            0.050505      0.030303        0.000000    0.020202
# 10        FLG            0.060606      0.060606        0.000000    0.000000
# 11     GLT1D1            0.050505      0.010101        0.000000    0.040404
# 12       HCN1            0.070707      0.060606        0.010101    0.000000
# 13      HMCN1            0.070707      0.070707        0.000000    0.000000
# 14       IDH1            0.070707      0.070707        0.000000    0.000000
# 15       LRP2            0.050505      0.040404        0.010101    0.000000
# 16     MAGEC1            0.050505      0.050505        0.000000    0.000000
# 17       MSH4            0.050505      0.050505        0.000000    0.000000
# 18      MUC16            0.080808      0.080808        0.000000    0.000000
# 19      MUC17            0.060606      0.060606        0.000000    0.000000
# 20      MXRA5            0.050505      0.050505        0.000000    0.000000
# 21        NF1            0.151515      0.020202        0.141414    0.000000
# 22     PIK3CA            0.101010      0.090909        0.010101    0.000000
# 23     PIK3R1            0.060606      0.050505        0.010101    0.000000
# 24      PKHD1            0.050505      0.040404        0.010101    0.000000
# 25       PTEN            0.272727      0.161616        0.111111    0.000000
# 26        RB1            0.101010      0.000000        0.101010    0.010101
# 27       RPL5            0.050505      0.010101        0.040404    0.000000
# 28       RYR2            0.090909      0.080808        0.020202    0.000000
# 29       RYR3            0.080808      0.070707        0.010101    0.000000
# 30      SETD2            0.050505      0.020202        0.020202    0.010101
# 31       TP53            0.323232      0.272727        0.050505    0.000000
# 32       TTC6            0.060606      0.030303        0.000000    0.030303
# 33      USH2A            0.050505      0.050505        0.000000    0.000000
