# %%
import pandas as pd
import numpy as np
import scipy.stats
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

import cptac
import cptac.utils as al

# %%
brain = cptac.Gbm()

brain.list_data()
# Out:
# Below are the dataframes contained in this dataset:
# 	acetylproteomics
# 		Dimensions: (110, 18767)
# 	circular_RNA
# 		Dimensions: (100, 3670)
# 	clinical
# 		Dimensions: (115, 21)
# 	CNV
# 		Dimensions: (99, 19907)
# 	experimental_design
# 		Dimensions: (115, 8)
# 	gene_fusion
# 		Dimensions: (2118, 8)
# 	lipidomics
# 		Dimensions: (88, 582)
# 	metabolomics
# 		Dimensions: (87, 134)
# 	miRNA
# 		Dimensions: (88, 2883)
# 	phosphoproteomics
# 		Dimensions: (110, 101347)
# 	proteomics
# 		Dimensions: (110, 11141)
# 	somatic_mutation
# 		Dimensions: (5807, 3)
# 	transcriptomics
# 		Dimensions: (109, 60483)

# %%
experimental_design = brain.get_experimental_design()
experimental_design.head()
# Out:
# Name      Patient_ID tumor_normal  tmt_plex tmt_channel  \
# Sample_ID
# S001       C3L-00104        tumor      11.0        129C
# S002       C3L-00365        tumor       2.0        128N
# S003       C3L-00674        tumor       4.0        131C
# S004       C3L-00677        tumor       7.0        129C
# S005       C3L-01040        tumor      11.0        128N
#
# Name                parent_sample_ids     aliquot_id  sample_mass_mg  \
# Sample_ID
# S001                     C3L-00104-01  CPT0092440003             NaN
# S002                     C3L-00365-01  CPT0002410011            46.0
# S003                     C3L-00674-71  CPT0064650003            55.0
# S004                     C3L-00677-72  CPT0071100003            49.0
# S005       C3L-01040-02, C3L-01040-03  CPT0171580008             NaN
#
# Name      sample_is_oct
# Sample_ID
# S001                NaN
# S002              False
# S003              False
# S004              False
# S005                NaN
